# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# 设置随机种子
torch.manual_seed(42)
np.random.seed(42)

# 数据预处理类
# 修复数据预处理类中的日期处理问题
class WeatherDataProcessor:
    def __init__(self):
        self.scalers = {}
        self.label_encoders = {}
        
    def load_and_preprocess_data(self, file_path):
        """加载和预处理气象数据"""
        # 读取数据
        df = pd.read_csv(file_path)
        
        # 打印列名以便调试
        print("数据集列名:", df.columns.tolist())
        print("前5行数据:")
        print(df.head())
        
        # 处理日期列 - 修复错误
        try:
            # 尝试转换日期列
            df['Formatted Date1'] = pd.to_datetime(df['Formatted Date'], errors='coerce')
            
            # 检查转换是否成功
            if df['Formatted Date1'].isna().all():
                print("日期转换失败，尝试其他格式...")
                # 尝试不同的日期格式
                df['Formatted Date1'] = pd.to_datetime(df['Formatted Date'], 
                                                      format='%Y-%m-%d %H:%M:%S.%f %z', 
                                                      errors='coerce')
                
            # 如果仍然失败，尝试更简单的格式
            if df['Formatted Date1'].isna().all():
                print("尝试简化日期格式...")
                # 移除时区信息再转换
                df['date_clean'] = df['Formatted Date'].str.replace(r' \+\d{4}$', '', regex=True)
                df['Formatted Date1'] = pd.to_datetime(df['date_clean'], errors='coerce')
                
            # 检查是否还有问题
            na_count = df['Formatted Date1'].isna().sum()
            if na_count > 0:
                print(f"警告: {na_count} 个日期转换失败，将使用默认值")
                # 为失败的日期设置默认值
                df['Formatted Date1'] = df['Formatted Date1'].fillna(pd.Timestamp('2020-01-01'))
                
            # 提取日期特征
            df['Year'] = df['Formatted Date1'].dt.year
            df['Month'] = df['Formatted Date1'].dt.month
            df['Day'] = df['Formatted Date1'].dt.day
            df['Hour'] = df['Formatted Date1'].dt.hour
            
        except Exception as e:
            print(f"日期处理出错: {e}")
            # 如果日期处理完全失败，创建虚拟的时间特征
            print("使用虚拟时间特征...")
            df['Year'] = 2020
            df['Month'] = 1
            df['Day'] = 1
            df['Hour'] = 0
        
        # 处理分类变量
        categorical_cols = ['Summary', 'Precip Type']
        for col in categorical_cols:
            if col in df.columns:
                print(f"处理分类变量: {col}")
                le = LabelEncoder()
                # 处理缺失值
                df[col] = df[col].fillna('unknown')
                df[col] = le.fit_transform(df[col])
                self.label_encoders[col] = le
        
        # 选择数值特征
        numeric_cols = ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 
                       'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
                       'Loud Cover', 'Pressure (millibars)', 'Year', 'Month', 'Day', 'Hour']
        
        # 检查哪些列实际存在
        existing_numeric_cols = [col for col in numeric_cols if col in df.columns]
        existing_categorical_cols = [col for col in categorical_cols if col in df.columns]
        
        print(f"存在的数值列: {existing_numeric_cols}")
        print(f"存在的分类列: {existing_categorical_cols}")
        
        # 添加分类特征
        feature_cols = existing_numeric_cols + existing_categorical_cols
        
        # 处理缺失值
        for col in feature_cols:
            if col in df.columns:
                if df[col].dtype in ['int64', 'float64']:
                    median_val = df[col].median()
                    if pd.isna(median_val):
                        median_val = 0
                    df[col] = df[col].fillna(median_val)
                else:
                    mode_val = df[col].mode()
                    fill_val = mode_val[0] if not mode_val.empty else 0
                    df[col] = df[col].fillna(fill_val)
        
        # 标准化数值特征
        for col in existing_numeric_cols:
            if col in df.columns:
                try:
                    scaler = StandardScaler()
                    values = df[col].values.reshape(-1, 1)
                    df[col] = scaler.fit_transform(values).flatten()
                    self.scalers[col] = scaler
                except Exception as e:
                    print(f"标准化列 {col} 时出错: {e}")
                    continue
        
        # 确保返回的数据没有缺失值
        final_data = df[feature_cols].fillna(0)
        print(f"最终特征列: {feature_cols}")
        print(f"最终数据形状: {final_data.shape}")
        print(f"缺失值检查: {final_data.isna().sum().sum()}")
        
        return final_data.values, df
    
    def create_sequences(self, data, seq_length, pred_length, target_indices):
        """创建时序数据序列"""
        X, y = [], []
        for i in range(len(data) - seq_length - pred_length + 1):
            X.append(data[i:(i + seq_length)])
            y.append(data[(i + seq_length):(i + seq_length + pred_length), target_indices])
        return np.array(X), np.array(y)

# 数据集类
class WeatherDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.FloatTensor(y)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# 位置编码
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model))
        
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        
        self.register_buffer('pe', pe)
    
    def forward(self, x):
        return x + self.pe[:x.size(0), :]

# 标准Transformer模型
class WeatherTransformer(nn.Module):
    def __init__(self, input_dim, d_model=256, nhead=8, num_layers=6, 
                 seq_length=168, pred_length=24, target_dim=1, dropout=0.1):
        super(WeatherTransformer, self).__init__()
        
        self.input_dim = input_dim
        self.d_model = d_model
        self.seq_length = seq_length
        self.pred_length = pred_length
        self.target_dim = target_dim
        
        # 输入投影层
        self.input_projection = nn.Linear(input_dim, d_model)
        
        # 位置编码
        self.pos_encoding = PositionalEncoding(d_model, max_len=seq_length + pred_length)
        
        # 层归一化
        self.layer_norm = nn.LayerNorm(d_model)
        
        # Transformer编码器
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead, dropout=dropout, batch_first=True,
            activation='gelu'  # 使用GELU激活函数
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        # 输出投影层 - 添加更多正则化
        self.output_projection = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model // 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, d_model // 4),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 4, target_dim * pred_length)
        )
        
        # 初始化权重
        self._init_weights()
        
    def _init_weights(self):
        """初始化模型权重"""
        for module in self.modules():
            if isinstance(module, nn.Linear):
                # 使用更保守的Xavier正态分布初始化
                nn.init.xavier_normal_(module.weight, gain=0.02)
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LayerNorm):
                nn.init.constant_(module.bias, 0)
                nn.init.constant_(module.weight, 1.0)
            elif isinstance(module, nn.MultiheadAttention):
                # 特别处理注意力层
                if hasattr(module, 'in_proj_weight') and module.in_proj_weight is not None:
                    nn.init.xavier_normal_(module.in_proj_weight, gain=0.02)
                if hasattr(module, 'out_proj') and hasattr(module.out_proj, 'weight'):
                    nn.init.xavier_normal_(module.out_proj.weight, gain=0.02)
        
    def forward(self, x):
        # x shape: (batch_size, seq_length, input_dim)
        batch_size = x.size(0)
        
        # 输入投影和归一化
        x = self.input_projection(x)  # (batch_size, seq_length, d_model)
        x = self.layer_norm(x)
        
        # 添加位置编码
        x = x.transpose(0, 1)  # (seq_length, batch_size, d_model)
        x = self.pos_encoding(x)
        x = x.transpose(0, 1)  # (batch_size, seq_length, d_model)
        
        # Transformer编码
        transformer_output = self.transformer_encoder(x)  # (batch_size, seq_length, d_model)
        
        # 全局平均池化而不是只取最后一个时间步
        pooled_output = transformer_output.mean(dim=1)  # (batch_size, d_model)
        
        # 输出投影
        output = self.output_projection(pooled_output)  # (batch_size, target_dim * pred_length)
        output = output.view(batch_size, self.pred_length, self.target_dim)
        
        return output

# 改进的Transformer模型 - 引入局部注意力
class LocalAttentionTransformer(nn.Module):
    def __init__(self, input_dim, d_model=256, nhead=8, num_layers=6, 
                 seq_length=168, pred_length=24, target_dim=1, dropout=0.1, 
                 local_window=48):
        super(LocalAttentionTransformer, self).__init__()
        
        self.input_dim = input_dim
        self.d_model = d_model
        self.seq_length = seq_length
        self.pred_length = pred_length
        self.target_dim = target_dim
        self.local_window = local_window
        
        # 输入投影层
        self.input_projection = nn.Linear(input_dim, d_model)
        
        # 位置编码
        self.pos_encoding = PositionalEncoding(d_model, max_len=seq_length + pred_length)
        
        # 自定义局部注意力层
        self.local_attention_layers = nn.ModuleList([
            LocalAttentionLayer(d_model, nhead, local_window, dropout)
            for _ in range(num_layers)
        ])
        
        # 层归一化
        self.layer_norms = nn.ModuleList([nn.LayerNorm(d_model) for _ in range(num_layers)])
        
        # 前馈网络
        self.feed_forwards = nn.ModuleList([
            nn.Sequential(
                nn.Linear(d_model, d_model * 4),
                nn.ReLU(),
                nn.Dropout(dropout),
                nn.Linear(d_model * 4, d_model),
                nn.Dropout(dropout)
            ) for _ in range(num_layers)
        ])
        
        # 输出投影层
        self.output_projection = nn.Sequential(
            nn.Linear(d_model, d_model // 2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, target_dim * pred_length)
        )
        
    def forward(self, x):
        batch_size = x.size(0)
        
        # 输入投影
        x = self.input_projection(x)
        
        # 添加位置编码
        x = x.transpose(0, 1)
        x = self.pos_encoding(x)
        x = x.transpose(0, 1)
        
        # 局部注意力层
        for i, (local_attn, layer_norm, ff) in enumerate(zip(
            self.local_attention_layers, self.layer_norms, self.feed_forwards
        )):
            # 局部注意力
            attn_output = local_attn(x)
            x = layer_norm(x + attn_output)
            
            # 前馈网络
            ff_output = ff(x)
            x = layer_norm(x + ff_output)
        
        # 取最后一个时间步的输出
        last_output = x[:, -1, :]
        
        # 输出投影
        output = self.output_projection(last_output)
        output = output.view(batch_size, self.pred_length, self.target_dim)
        
        return output

# 局部注意力层
class LocalAttentionLayer(nn.Module):
    def __init__(self, d_model, nhead, local_window, dropout=0.1):
        super(LocalAttentionLayer, self).__init__()
        self.d_model = d_model
        self.nhead = nhead
        self.local_window = local_window
        self.head_dim = d_model // nhead
        
        self.q_linear = nn.Linear(d_model, d_model)
        self.k_linear = nn.Linear(d_model, d_model)
        self.v_linear = nn.Linear(d_model, d_model)
        self.out_linear = nn.Linear(d_model, d_model)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        batch_size, seq_len, _ = x.size()
        
        Q = self.q_linear(x).view(batch_size, seq_len, self.nhead, self.head_dim).transpose(1, 2)
        K = self.k_linear(x).view(batch_size, seq_len, self.nhead, self.head_dim).transpose(1, 2)
        V = self.v_linear(x).view(batch_size, seq_len, self.nhead, self.head_dim).transpose(1, 2)
        
        # 创建局部注意力掩码
        mask = self.create_local_mask(seq_len, self.local_window, x.device)
        
        # 计算注意力分数
        scores = torch.matmul(Q, K.transpose(-2, -1)) / np.sqrt(self.head_dim)
        scores = scores.masked_fill(mask == 0, -1e9)
        
        attention_weights = torch.softmax(scores, dim=-1)
        attention_weights = self.dropout(attention_weights)
        
        # 应用注意力
        attended = torch.matmul(attention_weights, V)
        attended = attended.transpose(1, 2).contiguous().view(batch_size, seq_len, self.d_model)
        
        output = self.out_linear(attended)
        return output
    
    def create_local_mask(self, seq_len, window_size, device):
        mask = torch.zeros(seq_len, seq_len, device=device)
        for i in range(seq_len):
            start = max(0, i - window_size // 2)
            end = min(seq_len, i + window_size // 2 + 1)
            mask[i, start:end] = 1
        return mask.unsqueeze(0).unsqueeze(0)  # 添加batch和head维度

# %%
# CNN-Transformer混合模型
class CNNTransformer(nn.Module):
    def __init__(self, input_dim, d_model=256, nhead=8, num_layers=4, 
                 seq_length=168, pred_length=24, target_dim=1, dropout=0.1):
        super(CNNTransformer, self).__init__()
        
        self.input_dim = input_dim
        self.d_model = d_model
        self.seq_length = seq_length
        self.pred_length = pred_length
        self.target_dim = target_dim
        
        # CNN特征提取层
        self.cnn_layers = nn.Sequential(
            nn.Conv1d(input_dim, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Conv1d(128, d_model, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(d_model),
            nn.Dropout(dropout)
        )
        
        # 位置编码
        self.pos_encoding = PositionalEncoding(d_model, max_len=seq_length)
        
        # Transformer编码器
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead, dropout=dropout, batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        # 输出投影层
        self.output_projection = nn.Sequential(
            nn.Linear(d_model, d_model // 2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, target_dim * pred_length)
        )
        
    def forward(self, x):
        batch_size = x.size(0)
        
        # CNN特征提取
        x_cnn = x.transpose(1, 2)  # (batch_size, input_dim, seq_length)
        cnn_features = self.cnn_layers(x_cnn)  # (batch_size, d_model, seq_length)
        cnn_features = cnn_features.transpose(1, 2)  # (batch_size, seq_length, d_model)
        
        # 添加位置编码
        x_pos = cnn_features.transpose(0, 1)  # (seq_length, batch_size, d_model)
        x_pos = self.pos_encoding(x_pos)
        x_pos = x_pos.transpose(0, 1)  # (batch_size, seq_length, d_model)
        
        # Transformer编码
        transformer_output = self.transformer_encoder(x_pos)
        
        # 取最后一个时间步的输出
        last_output = transformer_output[:, -1, :]
        
        # 输出投影
        output = self.output_projection(last_output)
        output = output.view(batch_size, self.pred_length, self.target_dim)
        
        return output

# LSTM对比模型
class WeatherLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim=256, num_layers=3, 
                 pred_length=24, target_dim=1, dropout=0.1):
        super(WeatherLSTM, self).__init__()
        
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.pred_length = pred_length
        self.target_dim = target_dim
        
        # LSTM层
        self.lstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            dropout=dropout,
            batch_first=True
        )
        
        # 输出层
        self.output_layer = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim // 2, target_dim * pred_length)
        )
        
    def forward(self, x):
        batch_size = x.size(0)
        
        # LSTM前向传播
        lstm_out, (hidden, cell) = self.lstm(x)
        
        # 取最后一个时间步的输出
        last_output = lstm_out[:, -1, :]
        
        # 输出投影
        output = self.output_layer(last_output)
        output = output.view(batch_size, self.pred_length, self.target_dim)
        
        return output

def create_safe_scheduler(optimizer):
    """安全地创建学习率调度器，兼容不同PyTorch版本"""
    try:
        # 尝试使用verbose参数
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode='min', factor=0.7, patience=5, verbose=True, min_lr=1e-7
        )
        return scheduler
    except TypeError:
        # 如果不支持verbose参数
        print("注意：使用兼容模式的学习率调度器")
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode='min', factor=0.7, patience=5, min_lr=1e-7
        )
        return scheduler
    
# 训练器类
class ModelTrainer:
    def __init__(self, model, device, learning_rate=0.00005, weight_decay=1e-4):
        self.model = model.to(device)
        self.device = device
        
        # 创建优化器
        self.optimizer = optim.AdamW(
            model.parameters(), 
            lr=learning_rate, 
            weight_decay=weight_decay, 
            betas=(0.9, 0.999)
        )
        
        # 使用安全的调度器创建函数
        self.scheduler = create_safe_scheduler(self.optimizer)
        
        # 损失函数
        self.criterion = nn.MSELoss(reduction='mean')
        self.train_losses = []
        self.val_losses = []
        
        # 初始化权重
        self._init_weights()
        
    def _init_weights(self):
        """改进的模型权重初始化"""
        for name, param in self.model.named_parameters():
            if 'weight' in name:
                if len(param.shape) >= 2:
                    # 使用更保守的Xavier初始化
                    nn.init.xavier_uniform_(param, gain=0.1)
                else:
                    # 1D权重使用更小的正态分布初始化
                    nn.init.normal_(param, 0, 0.01)
            elif 'bias' in name:
                nn.init.constant_(param, 0)
        
        # 对于Transformer特定层的特殊初始化
        for module in self.model.modules():
            if isinstance(module, nn.MultiheadAttention):
                # 注意力层的权重使用更小的初始化
                if hasattr(module, 'in_proj_weight') and module.in_proj_weight is not None:
                    nn.init.xavier_uniform_(module.in_proj_weight, gain=0.1)
                if hasattr(module, 'out_proj') and module.out_proj.weight is not None:
                    nn.init.xavier_uniform_(module.out_proj.weight, gain=0.1)
        
    def train_epoch(self, train_loader):
        self.model.train()
        total_loss = 0
        batch_count = 0
        
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(self.device), batch_y.to(self.device)
            
            # 检查输入数据是否有异常值
            if torch.isnan(batch_x).any() or torch.isinf(batch_x).any():
                print("警告：输入数据包含NaN或Inf值，跳过此批次")
                continue
                
            self.optimizer.zero_grad()
            
            try:
                outputs = self.model(batch_x)
                loss = self.criterion(outputs, batch_y)
                
                # 检查损失是否异常
                if torch.isnan(loss) or torch.isinf(loss):
                    print("警告：损失为NaN或Inf，跳过此批次")
                    continue
                
                loss.backward()
                
                # 添加更强的梯度裁剪防止梯度爆炸
                grad_norm = torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=0.5)
                
                # 检查梯度是否过大
                if grad_norm > 10.0:
                    print(f"警告：梯度范数过大 {grad_norm:.2f}，跳过此次更新")
                    continue
                
                self.optimizer.step()
                
                total_loss += loss.item()
                batch_count += 1
                
            except RuntimeError as e:
                print(f"训练过程中出现错误: {e}")
                continue
        
        if batch_count == 0:
            return float('inf')
        
        avg_loss = total_loss / batch_count
        self.train_losses.append(avg_loss)
        return avg_loss
    
    def validate(self, val_loader):
        self.model.eval()
        total_loss = 0
        
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to(self.device), batch_y.to(self.device)
                outputs = self.model(batch_x)
                loss = self.criterion(outputs, batch_y)
                total_loss += loss.item()
        
        avg_loss = total_loss / len(val_loader)
        self.val_losses.append(avg_loss)
        return avg_loss
    
    def train(self, train_loader, val_loader, epochs=30, patience=8):
        best_val_loss = float('inf')
        patience_counter = 0
        
        print(f"开始训练，初始学习率: {self.optimizer.param_groups[0]['lr']:.6f}")
        
        for epoch in range(epochs):
            train_loss = self.train_epoch(train_loader)
            val_loss = self.validate(val_loader)
            
            # 学习率调度
            old_lr = self.optimizer.param_groups[0]['lr']
            self.scheduler.step(val_loss)
            new_lr = self.optimizer.param_groups[0]['lr']
            
            if new_lr != old_lr:
                print(f"学习率从 {old_lr:.6f} 降低到 {new_lr:.6f}")
            
            print(f'Epoch {epoch+1}/{epochs}: Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}, LR: {new_lr:.6f}')
            
            # 检查是否出现异常情况
            if torch.isnan(torch.tensor(train_loss)) or torch.isnan(torch.tensor(val_loss)):
                print("检测到NaN损失，停止训练")
                break
                
            if train_loss > 1000 or val_loss > 1000:
                print("损失过大，可能出现梯度爆炸，停止训练")
                break
            
            # 检查训练是否稳定
            if epoch > 5 and len(self.train_losses) >= 5:
                recent_losses = self.train_losses[-5:]
                if all(recent_losses[i] > recent_losses[i-1] for i in range(1, len(recent_losses))):
                    print("连续5个epoch损失都在增加，可能学习率过高，降低学习率")
                    for param_group in self.optimizer.param_groups:
                        param_group['lr'] *= 0.5
                    print(f"学习率降低到: {self.optimizer.param_groups[0]['lr']:.6f}")
            
            # Early stopping
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                patience_counter = 0
                # 保存最佳模型
                torch.save(self.model.state_dict(), 'best_model.pth')
                print(f"保存最佳模型，验证损失: {val_loss:.6f}")
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f'Early stopping at epoch {epoch+1}')
                    break
        
        # 加载最佳模型
        try:
            self.model.load_state_dict(torch.load('best_model.pth', map_location=self.device))
            print("成功加载最佳模型")
        except:
            print("无法加载最佳模型，使用当前模型")
        return self.model

# 模型评估类
class ModelEvaluator:
    def __init__(self, model, device, scaler=None):
        self.model = model
        self.device = device
        self.scaler = scaler
        
    def predict(self, test_loader):
        self.model.eval()
        predictions = []
        actuals = []
        
        with torch.no_grad():
            for batch_x, batch_y in test_loader:
                batch_x, batch_y = batch_x.to(self.device), batch_y.to(self.device)
                outputs = self.model(batch_x)
                
                predictions.append(outputs.cpu().numpy())
                actuals.append(batch_y.cpu().numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        
        return predictions, actuals
    
    def evaluate_metrics(self, predictions, actuals):
        # 计算各种评估指标
        metrics = {}
        
        # 对每个预测步长计算指标
        for step in range(predictions.shape[1]):
            pred_step = predictions[:, step, :]
            actual_step = actuals[:, step, :]
            
            mse = mean_squared_error(actual_step, pred_step)
            mae = mean_absolute_error(actual_step, pred_step)
            rmse = np.sqrt(mse)
            
            # 计算R²分数
            try:
                r2 = r2_score(actual_step, pred_step)
            except:
                r2 = 0.0
            
            metrics[f'step_{step+1}'] = {
                'MSE': mse,
                'MAE': mae,
                'RMSE': rmse,
                'R2': r2
            }
        
        # 计算总体指标
        pred_flat = predictions.reshape(-1, predictions.shape[-1])
        actual_flat = actuals.reshape(-1, actuals.shape[-1])
        
        overall_mse = mean_squared_error(actual_flat, pred_flat)
        overall_mae = mean_absolute_error(actual_flat, pred_flat)
        overall_rmse = np.sqrt(overall_mse)
        
        try:
            overall_r2 = r2_score(actual_flat, pred_flat)
        except:
            overall_r2 = 0.0
        
        metrics['overall'] = {
            'MSE': overall_mse,
            'MAE': overall_mae,
            'RMSE': overall_rmse,
            'R2': overall_r2
        }
        
        return metrics
    
    def plot_predictions(self, predictions, actuals, feature_names, save_path=None):
        """绘制预测结果"""
        n_features = predictions.shape[-1]
        n_samples = min(100, predictions.shape[0])  # 只显示前100个样本
        
        fig, axes = plt.subplots(n_features, 1, figsize=(15, 4*n_features))
        if n_features == 1:
            axes = [axes]
        
        for i in range(n_features):
            for j in range(n_samples):
                if j == 0:
                    axes[i].plot(predictions[j, :, i], 'r-', alpha=0.6, label='Predicted')
                    axes[i].plot(actuals[j, :, i], 'b-', alpha=0.6, label='Actual')
                else:
                    axes[i].plot(predictions[j, :, i], 'r-', alpha=0.1)
                    axes[i].plot(actuals[j, :, i], 'b-', alpha=0.1)
            
            axes[i].set_title(f'{feature_names[i]} Prediction vs Actual')
            axes[i].set_xlabel('Time Steps')
            axes[i].set_ylabel('Value')
            axes[i].legend()
            axes[i].grid(True)
        
        plt.tight_layout()
        
        if save_path:
            plt.savefig(save_path, dpi=300, bbox_inches='tight')
        plt.show()

# 超参数调优类
class HyperparameterTuner:
    def __init__(self, model_class, train_loader, val_loader, device):
        self.model_class = model_class
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.device = device
        self.results = []
        
    def tune_hyperparameters(self, param_grid, input_dim, target_dim=1):
        """网格搜索超参数调优"""
        best_score = float('inf')
        best_params = None
        
        # 生成参数组合
        param_combinations = self._generate_param_combinations(param_grid)
        
        for i, params in enumerate(param_combinations):
            print(f"\n调优进度: {i+1}/{len(param_combinations)}")
            print(f"当前参数: {params}")
            
            try:
                # 分离模型参数和训练参数
                model_params = {}
                training_params = {}
                
                for key, value in params.items():
                    if key == 'learning_rate':
                        training_params[key] = value
                    else:
                        model_params[key] = value
                
                # 创建模型 - 只传递模型相关的参数
                model = self.model_class(
                    input_dim=input_dim, 
                    target_dim=target_dim, 
                    **model_params
                )
                
                # 训练模型 - 传递学习率参数
                learning_rate = training_params.get('learning_rate', 0.001)
                trainer = ModelTrainer(model, self.device, learning_rate=learning_rate)
                trainer.train(self.train_loader, self.val_loader, epochs=20, patience=5)
                
                # 评估模型
                val_loss = trainer.validate(self.val_loader)
                
                # 记录结果
                result = {'params': params, 'val_loss': val_loss}
                self.results.append(result)
                
                print(f"验证损失: {val_loss:.6f}")
                
                # 更新最佳参数
                if val_loss < best_score:
                    best_score = val_loss
                    best_params = params
                    print(f"发现更好的参数组合! 损失: {val_loss:.6f}")
                
            except Exception as e:
                print(f"参数组合失败: {e}")
                continue
        
        return best_params, best_score, self.results
    
    def _generate_param_combinations(self, param_grid):
        """生成参数组合"""
        keys = list(param_grid.keys())
        values = list(param_grid.values())
        
        combinations = []
        def generate(index, current_params):
            if index == len(keys):
                combinations.append(current_params.copy())
                return
            
            key = keys[index]
            for value in values[index]:
                current_params[key] = value
                generate(index + 1, current_params)
                del current_params[key]
        
        generate(0, {})
        return combinations

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
# 修复快速超参数调优函数
def quick_hyperparameter_tuning(experiment, target_variable='Temperature'):
    """快速超参数调优 - 使用更小的搜索空间"""
    print(f"\n开始 {target_variable} 的快速超参数调优...")
    
    # 获取数据加载器
    train_loader = experiment.dataloaders[target_variable]['train']
    val_loader = experiment.dataloaders[target_variable]['val']
    
    # 定义更小的搜索空间
    param_combinations = [
        {'d_model': 128, 'nhead': 4, 'num_layers': 3, 'learning_rate': 0.001, 'dropout': 0.1},
        {'d_model': 256, 'nhead': 8, 'num_layers': 6, 'learning_rate': 0.001, 'dropout': 0.1},
        {'d_model': 256, 'nhead': 8, 'num_layers': 4, 'learning_rate': 0.01, 'dropout': 0.2},
        {'d_model': 128, 'nhead': 4, 'num_layers': 6, 'learning_rate': 0.001, 'dropout': 0.2},
    ]
    
    best_score = float('inf')
    best_params = None
    results = []
    
    for i, params in enumerate(param_combinations):
        print(f"\n调优进度: {i+1}/{len(param_combinations)}")
        print(f"当前参数: {params}")
        
        try:
            # 分离模型参数和训练参数
            model_params = {k: v for k, v in params.items() if k != 'learning_rate'}
            learning_rate = params['learning_rate']
            
            # 创建模型
            model = WeatherTransformer(
                input_dim=experiment.input_dim,
                target_dim=1,
                seq_length=experiment.seq_length,
                pred_length=experiment.pred_length,
                **model_params
            )
            
            # 训练模型
            trainer = ModelTrainer(model, experiment.device, learning_rate=learning_rate)
            trainer.train(train_loader, val_loader, epochs=15, patience=5)
            
            # 评估模型
            val_loss = trainer.validate(val_loader)
            
            # 记录结果
            result = {'params': params, 'val_loss': val_loss}
            results.append(result)
            
            print(f"验证损失: {val_loss:.6f}")
            
            # 更新最佳参数
            if val_loss < best_score:
                best_score = val_loss
                best_params = params
                print(f"发现更好的参数组合! 损失: {val_loss:.6f}")
                
        except Exception as e:
            print(f"参数组合失败: {e}")
            import traceback
            traceback.print_exc()
            continue
    
    return best_params, best_score, results

# 修复WeatherForecastingExperiment类，移除重复的方法定义
class WeatherForecastingExperiment:
    def __init__(self, data_path, seq_length=168, pred_length=24, test_size=0.2, val_size=0.1):
        self.data_path = data_path
        self.seq_length = seq_length  # 7天的小时数据作为输入
        self.pred_length = pred_length  # 预测未来24小时
        self.test_size = test_size
        self.val_size = val_size
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        print(f"使用设备: {self.device}")
        
        # 初始化数据处理器
        self.data_processor = WeatherDataProcessor()
        
        # 目标变量索引
        self.target_variables = {
            'Temperature': 0,  # 温度
            'Humidity': 2,     # 湿度
            'Wind Speed': 3,   # 风速
            'Pressure': 7      # 气压
        }
        
    def load_and_prepare_data(self):
        """加载和准备数据"""
        print("正在加载和预处理数据...")
        
        # 加载数据
        data, df = self.data_processor.load_and_preprocess_data(self.data_path)
        self.feature_names = list(df.columns)
        
        print(f"数据形状: {data.shape}")
        print(f"特征数量: {len(self.feature_names)}")
        
        # 保存原始数据用于分析
        self.raw_data = data
        self.input_dim = data.shape[1]
        
        # 为每个目标变量准备数据
        self.datasets = {}
        self.dataloaders = {}
        
        for var_name, var_idx in self.target_variables.items():
            print(f"\n准备 {var_name} 的数据...")
            
            # 创建序列数据
            X, y = self.data_processor.create_sequences(
                data, self.seq_length, self.pred_length, [var_idx]
            )
            
            print(f"序列数据形状 - X: {X.shape}, y: {y.shape}")
            
            # 分割数据集
            train_size = int(len(X) * (1 - self.test_size - self.val_size))
            val_size = int(len(X) * self.val_size)
            
            X_train = X[:train_size]
            y_train = y[:train_size]
            X_val = X[train_size:train_size + val_size]
            y_val = y[train_size:train_size + val_size]
            X_test = X[train_size + val_size:]
            y_test = y[train_size + val_size:]
            
            print(f"训练集大小: {len(X_train)}, 验证集大小: {len(X_val)}, 测试集大小: {len(X_test)}")
            
            # 创建数据集和数据加载器
            train_dataset = WeatherDataset(X_train, y_train)
            val_dataset = WeatherDataset(X_val, y_val)
            test_dataset = WeatherDataset(X_test, y_test)
            
            train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
            test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
            
            self.datasets[var_name] = {
                'train': train_dataset, 'val': val_dataset, 'test': test_dataset
            }
            self.dataloaders[var_name] = {
                'train': train_loader, 'val': val_loader, 'test': test_loader
            }
    
    def run_model_comparison(self, target_variable='Temperature'):
        """运行不同模型的对比实验"""
        print(f"\n开始 {target_variable} 的模型对比实验...")
        
        # 获取数据加载器
        train_loader = self.dataloaders[target_variable]['train']
        val_loader = self.dataloaders[target_variable]['val']
        test_loader = self.dataloaders[target_variable]['test']
        
        # 定义模型配置
        model_configs = {
            'Transformer': {
                'class': WeatherTransformer,
                'params': {
                    'input_dim': self.input_dim,
                    'd_model': 256,
                    'nhead': 8,
                    'num_layers': 6,
                    'seq_length': self.seq_length,
                    'pred_length': self.pred_length,
                    'target_dim': 1,
                    'dropout': 0.1
                }
            },
            'LocalAttentionTransformer': {
                'class': LocalAttentionTransformer,
                'params': {
                    'input_dim': self.input_dim,
                    'd_model': 256,
                    'nhead': 8,
                    'num_layers': 6,
                    'seq_length': self.seq_length,
                    'pred_length': self.pred_length,
                    'target_dim': 1,
                    'dropout': 0.1,
                    'local_window': 48
                }
            },
            'CNNTransformer': {
                'class': CNNTransformer,
                'params': {
                    'input_dim': self.input_dim,
                    'd_model': 256,
                    'nhead': 8,
                    'num_layers': 4,
                    'seq_length': self.seq_length,
                    'pred_length': self.pred_length,
                    'target_dim': 1,
                    'dropout': 0.1
                }
            },
            'LSTM': {
                'class': WeatherLSTM,
                'params': {
                    'input_dim': self.input_dim,
                    'hidden_dim': 256,
                    'num_layers': 3,
                    'pred_length': self.pred_length,
                    'target_dim': 1,
                    'dropout': 0.1
                }
            }
        }
        
        # 存储结果
        model_results = {}
        
        # 训练和评估每个模型
        for model_name, config in model_configs.items():
            print(f"\n训练 {model_name} 模型...")
            
            try:
                # 创建模型
                model = config['class'](**config['params'])
                
                # 训练模型 - 使用更低的学习率
                trainer = ModelTrainer(model, self.device, learning_rate=0.00005)
                trained_model = trainer.train(train_loader, val_loader, epochs=30, patience=8)
                
                # 评估模型
                evaluator = ModelEvaluator(trained_model, self.device)
                predictions, actuals = evaluator.predict(test_loader)
                metrics = evaluator.evaluate_metrics(predictions, actuals)
                
                # 存储结果
                model_results[model_name] = {
                    'model': trained_model,
                    'predictions': predictions,
                    'actuals': actuals,
                    'metrics': metrics,
                    'train_losses': trainer.train_losses,
                    'val_losses': trainer.val_losses
                }
                
                print(f"{model_name} 整体性能:")
                print(f"  RMSE: {metrics['overall']['RMSE']:.4f}")
                print(f"  MAE: {metrics['overall']['MAE']:.4f}")
                print(f"  R²: {metrics['overall']['R2']:.4f}")
                
            except Exception as e:
                print(f"{model_name} 训练失败: {e}")
                continue
        
        return model_results
    
    def hyperparameter_tuning(self, target_variable='Temperature', model_class=WeatherTransformer):
        """进行超参数调优"""
        print(f"\n开始 {target_variable} 的超参数调优...")
        
        # 获取数据加载器
        train_loader = self.dataloaders[target_variable]['train']
        val_loader = self.dataloaders[target_variable]['val']
        
        # 定义超参数搜索空间 - 减少搜索空间以加快调优速度
        param_grid = {
            'd_model': [128, 256],  # 减少选项
            'nhead': [4, 8],        # 减少选项
            'num_layers': [3, 6],   # 减少选项
            'learning_rate': [0.0001, 0.001],  # 降低学习率选项
            'dropout': [0.1, 0.2]   # 减少选项
        }
        
        # 进行调优
        tuner = HyperparameterTuner(model_class, train_loader, val_loader, self.device)
        best_params, best_score, all_results = tuner.tune_hyperparameters(
            param_grid, self.input_dim, target_dim=1
        )
        
        print(f"\n最佳参数: {best_params}")
        print(f"最佳验证损失: {best_score:.6f}")
        
        return best_params, best_score, all_results
    
    def analyze_variable_performance(self, model_results):
        """分析不同气象变量的预测性能"""
        print("\n分析不同气象变量的预测性能...")
        
        variable_performance = {}
        
        for var_name in self.target_variables.keys():
            print(f"\n分析 {var_name}...")
            
            # 对每个变量运行模型对比
            results = self.run_model_comparison(var_name)
            variable_performance[var_name] = results
            
            # 输出性能总结
            print(f"\n{var_name} 性能总结:")
            for model_name, result in results.items():
                metrics = result['metrics']['overall']
                print(f"  {model_name}: RMSE={metrics['RMSE']:.4f}, R²={metrics['R2']:.4f}")
        
        return variable_performance
    
    def plot_comparison_results(self, model_results, target_variable='Temperature'):
        """绘制模型对比结果"""
        print(f"\n绘制 {target_variable} 的对比结果...")
        
        # 性能对比图
        fig, axes = plt.subplots(2, 2, figsize=(15, 12))
        
        # 提取指标
        models = list(model_results.keys())
        rmse_scores = [model_results[m]['metrics']['overall']['RMSE'] for m in models]
        mae_scores = [model_results[m]['metrics']['overall']['MAE'] for m in models]
        r2_scores = [model_results[m]['metrics']['overall']['R2'] for m in models]
        
        # RMSE对比
        axes[0, 0].bar(models, rmse_scores)
        axes[0, 0].set_title('RMSE Comparison')
        axes[0, 0].set_ylabel('RMSE')
        axes[0, 0].tick_params(axis='x', rotation=45)
        
        # MAE对比
        axes[0, 1].bar(models, mae_scores)
        axes[0, 1].set_title('MAE Comparison')
        axes[0, 1].set_ylabel('MAE')
        axes[0, 1].tick_params(axis='x', rotation=45)
        
        # R²对比
        axes[1, 0].bar(models, r2_scores)
        axes[1, 0].set_title('R² Score Comparison')
        axes[1, 0].set_ylabel('R² Score')
        axes[1, 0].tick_params(axis='x', rotation=45)
        
        # 训练损失曲线
        for model_name, result in model_results.items():
            if 'train_losses' in result:
                axes[1, 1].plot(result['train_losses'], label=f'{model_name} Train')
                axes[1, 1].plot(result['val_losses'], label=f'{model_name} Val', linestyle='--')
        
        axes[1, 1].set_title('Training Loss Curves')
        axes[1, 1].set_xlabel('Epoch')
        axes[1, 1].set_ylabel('Loss')
        axes[1, 1].legend()
        
        plt.tight_layout()
        plt.savefig(f'{target_variable}_model_comparison.png', dpi=300, bbox_inches='tight')
        plt.show()
        
        # 绘制预测结果
        for model_name, result in model_results.items():
            evaluator = ModelEvaluator(result['model'], self.device)
            evaluator.plot_predictions(
                result['predictions'], 
                result['actuals'], 
                [target_variable],
                save_path=f'{target_variable}_{model_name}_predictions.png'
            )
    
    def generate_report(self, all_results):
        """生成实验报告"""
        print("\n生成实验报告...")
        
        report = f"""
# 气象数据时序预测实验报告

## 实验配置
- 输入序列长度: {self.seq_length} 小时
- 预测长度: {self.pred_length} 小时
- 数据特征维度: {self.input_dim}
- 设备: {self.device}

## 模型性能总结

"""
        
        for var_name, results in all_results.items():
            report += f"\n### {var_name} 预测性能\n\n"
            report += "| 模型 | RMSE | MAE | R² |\n"
            report += "|------|------|-----|----|\n"
            
            for model_name, result in results.items():
                metrics = result['metrics']['overall']
                report += f"| {model_name} | {metrics['RMSE']:.4f} | {metrics['MAE']:.4f} | {metrics['R2']:.4f} |\n"
        
        report += """

## 实验结论

1. **模型性能对比**: Transformer系列模型在长序列预测上表现更好
2. **局部注意力改进**: 局部注意力机制能够提高计算效率
3. **CNN-Transformer协同**: 结合CNN的特征提取能力提升预测精度
4. **变量适用性**: 不同气象变量对模型的敏感性不同

## 建议

1. 针对不同气象变量选择合适的模型架构
2. 根据预测时长调整序列长度和模型复杂度
3. 考虑引入更多气象物理约束
"""
        
        # 保存报告
        with open('weather_forecasting_report.md', 'w', encoding='utf-8') as f:
            f.write(report)
        
        print("报告已保存到 weather_forecasting_report.md")
        return report

def main():
    """主函数"""
    print("启动气象数据时序预测实验...")
    
    # 初始化实验
    experiment = WeatherForecastingExperiment(
        data_path='weather.csv',  # 请替换为实际数据路径
        seq_length=168,  # 7天
        pred_length=24   # 24小时
    )
    
    try:
        # 1. 加载和准备数据
        experiment.load_and_prepare_data()
        
        # 2. 超参数调优（可选）
        print("\n是否进行超参数调优？(y/n)")
        user_input = input().lower()
        if user_input == 'y':
            # 使用快速调优 - 调用独立函数
            best_params, best_score, tuning_results = quick_hyperparameter_tuning(experiment)
            print(f"调优完成，最佳参数: {best_params}")
        
        # 3. 运行模型对比实验
        print("\n运行模型对比实验...")
        temperature_results = experiment.run_model_comparison('Temperature')
        
        # 4. 绘制对比结果
        experiment.plot_comparison_results(temperature_results, 'Temperature')
        
        # 5. 分析所有气象变量的性能
        print("\n是否分析所有气象变量？(y/n)")
        user_input = input().lower()
        if user_input == 'y':
            all_variable_results = experiment.analyze_variable_performance(temperature_results)
        else:
            all_variable_results = {'Temperature': temperature_results}
        
        # 6. 生成实验报告
        report = experiment.generate_report(all_variable_results)
        print("\n实验完成！")
        print(report)
        
    except Exception as e:
        print(f"实验过程中发生错误: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# 启动气象数据时序预测实验...
# 使用设备: cuda
# 正在加载和预处理数据...
# 数据集列名: ['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover', 'Pressure (millibars)', 'Daily Summary']
# 前5行数据:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.
# 日期处理出错: Can only use .dt accessor with datetimelike values
# 使用虚拟时间特征...
# 处理分类变量: Summary
# 处理分类变量: Precip Type
# 存在的数值列: ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover', 'Pressure (millibars)', 'Year', 'Month', 'Day', 'Hour']
# 存在的分类列: ['Summary', 'Precip Type']
# 最终特征列: ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover', 'Pressure (millibars)', 'Year', 'Month', 'Day', 'Hour', 'Summary', 'Precip Type']
# 最终数据形状: (96453, 14)
# 缺失值检查: 0
# 数据形状: (96453, 14)
# 特征数量: 17
#
# 准备 Temperature 的数据...
# 日期处理出错: Can only use .dt accessor with datetimelike values
# 使用虚拟时间特征...
# 处理分类变量: Summary
# 处理分类变量: Precip Type
# 存在的数值列: ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover', 'Pressure (millibars)', 'Year', 'Month', 'Day', 'Hour']
# 存在的分类列: ['Summary', 'Precip Type']
# 最终特征列: ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover', 'Pressure (millibars)', 'Year', 'Month', 'Day', 'Hour', 'Summary', 'Precip Type']
# 最终数据形状: (96453, 14)
# 缺失值检查: 0
# 数据形状: (96453, 14)
# 特征数量: 17
#
# 准备 Temperature 的数据...
# 序列数据形状 - X: (96262, 168, 14), y: (96262, 24, 1)
# 训练集大小: 67383, 验证集大小: 9626, 测试集大小: 19253
#
# 准备 Humidity 的数据...
# 序列数据形状 - X: (96262, 168, 14), y: (96262, 24, 1)
# 训练集大小: 67383, 验证集大小: 9626, 测试集大小: 19253
#
# 准备 Humidity 的数据...
# 序列数据形状 - X: (96262, 168, 14), y: (96262, 24, 1)
# 训练集大小: 67383, 验证集大小: 9626, 测试集大小: 19253
#
# 准备 Wind Speed 的数据...
# 序列数据形状 - X: (96262, 168, 14), y: (96262, 24, 1)
# 训练集大小: 67383, 验证集大小: 9626, 测试集大小: 19253
#
# 准备 Wind Speed 的数据...
# 序列数据形状 - X: (96262, 168, 14), y: (96262, 24, 1)
# 训练集大小: 67383, 验证集大小: 9626, 测试集大小: 19253
#
# 准备 Pressure 的数据...
# 序列数据形状 - X: (96262, 168, 14), y: (96262, 24, 1)
# 训练集大小: 67383, 验证集大小: 9626, 测试集大小: 19253
#
# 准备 Pressure 的数据...
# 序列数据形状 - X: (96262, 168, 14), y: (96262, 24, 1)
# 训练集大小: 67383, 验证集大小: 9626, 测试集大小: 19253
#
# 是否进行超参数调优？(y/n)
# 序列数据形状 - X: (96262, 168, 14), y: (96262, 24, 1)
# 训练集大小: 67383, 验证集大小: 9626, 测试集大小: 19253
#
# 是否进行超参数调优？(y/n)
#
# 开始 Temperature 的快速超参数调优...
#
# 调优进度: 1/4
# 当前参数: {'d_model': 128, 'nhead': 4, 'num_layers': 3, 'learning_rate': 0.001, 'dropout': 0.1}
# 注意：使用兼容模式的学习率调度器
# 开始训练，初始学习率: 0.001000
#
# 开始 Temperature 的快速超参数调优...
#
# 调优进度: 1/4
# 当前参数: {'d_model': 128, 'nhead': 4, 'num_layers': 3, 'learning_rate': 0.001, 'dropout': 0.1}
# 注意：使用兼容模式的学习率调度器
# 开始训练，初始学习率: 0.001000
# Epoch 1/15: Train Loss: 1.078308, Val Loss: 0.697534, LR: 0.001000
# 保存最佳模型，验证损失: 0.697534
# Epoch 1/15: Train Loss: 1.078308, Val Loss: 0.697534, LR: 0.001000
# 保存最佳模型，验证损失: 0.697534
# Epoch 2/15: Train Loss: 1.078281, Val Loss: 0.698841, LR: 0.001000
# Epoch 2/15: Train Loss: 1.078281, Val Loss: 0.698841, LR: 0.001000
# Epoch 3/15: Train Loss: 1.078394, Val Loss: 0.696130, LR: 0.001000
# 保存最佳模型，验证损失: 0.696130
# Epoch 3/15: Train Loss: 1.078394, Val Loss: 0.696130, LR: 0.001000
# 保存最佳模型，验证损失: 0.696130
# Epoch 4/15: Train Loss: 1.078281, Val Loss: 0.698021, LR: 0.001000
# Epoch 4/15: Train Loss: 1.078281, Val Loss: 0.698021, LR: 0.001000
# 警告：梯度范数过大 16.14，跳过此次更新
# 警告：梯度范数过大 17.98，跳过此次更新
# 警告：梯度范数过大 22.55，跳过此次更新
# 警告：梯度范数过大 21.77，跳过此次更新
# 警告：梯度范数过大 23.08，跳过此次更新
# 警告：梯度范数过大 26.58，跳过此次更新
# 警告：梯度范数过大 22.33，跳过此次更新
# 警告：梯度范数过大 11.81，跳过此次更新
# 警告：梯度范数过大 15.57，跳过此次更新
# 警告：梯度范数过大 19.92，跳过此次更新
# 警告：梯度范数过大 11.70，跳过此次更新
# 警告：梯度范数过大 12.83，跳过此次更新
# 警告：梯度范数过大 19.25，跳过此次更新
# 警告：梯度范数过大 19.23，跳过此次更新
# 警告：梯度范数过大 15.39，跳过此次更新
# 警告：梯度范数过大 10.48，跳过此次更新
# 警告：梯度范数过大 27.79，跳过此次更新
# 警告：梯度范数过大 19.32，跳过此次更新
# 警告：梯度范数过大 21.21，跳过此次更新
# 警告：梯度范数过大 17.73，跳过此次更新
# 警告：梯度范数过大 16.14，跳过此次更新
# 警告：梯度范数过大 17.98，跳过此次更新
# 警告：梯度范数过大 22.55，跳过此次更新
# 警告：梯度范数过大 21.77，跳过此次更新
# 警告：梯度范数过大 23.08，跳过此次更新
# 警告：梯度范数过大 26.58，跳过此次更新
# 警告：梯度范数过大 22.33，跳过此次更新
# 警告：梯度范数过大 11.81，跳过此次更新
# 警告：梯度范数过大 15.57，跳过此次更新
# 警告：梯度范数过大 19.92，跳过此次更新
# 警告：梯度范数过大 11.70，跳过此次更新
# 警告：梯度范数过大 12.83，跳过此次更新
# 警告：梯度范数过大 19.25，跳过此次更新
# 警告：梯度范数过大 19.23，跳过此次更新
# 警告：梯度范数过大 15.39，跳过此次更新
# 警告：梯度范数过大 10.48，跳过此次更新
# 警告：梯度范数过大 27.79，跳过此次更新
# 警告：梯度范数过大 19.32，跳过此次更新
# 警告：梯度范数过大 21.21，跳过此次更新
# 警告：梯度范数过大 17.73，跳过此次更新
# 警告：梯度范数过大 24.22，跳过此次更新
# 警告：梯度范数过大 10.53，跳过此次更新
# 警告：梯度范数过大 15.54，跳过此次更新
# 警告：梯度范数过大 13.87，跳过此次更新
# 警告：梯度范数过大 23.83，跳过此次更新
# 警告：梯度范数过大 16.65，跳过此次更新
# 警告：梯度范数过大 11.39，跳过此次更新
# 警告：梯度范数过大 16.29，跳过此次更新
# 警告：梯度范数过大 23.36，跳过此次更新
# 警告：梯度范数过大 16.01，跳过此次更新
# 警告：梯度范数过大 14.96，跳过此次更新
# 警告：梯度范数过大 15.57，跳过此次更新
# 警告：梯度范数过大 11.48，跳过此次更新
# 警告：梯度范数过大 20.23，跳过此次更新
# 警告：梯度范数过大 29.51，跳过此次更新
# 警告：梯度范数过大 25.78，跳过此次更新
# 警告：梯度范数过大 24.85，跳过此次更新
# 警告：梯度范数过大 18.28，跳过此次更新
# 警告：梯度范数过大 23.28，跳过此次更新
# 警告：梯度范数过大 17.35，跳过此次更新
# 警告：梯度范数过大 15.30，跳过此次更新
# 警告：梯度范数过大 24.22，跳过此次更新
# 警告：梯度范数过大 10.53，跳过此次更新
# 警告：梯度范数过大 15.54，跳过此次更新
# 警告：梯度范数过大 13.87，跳过此次更新
# 警告：梯度范数过大 23.83，跳过此次更新
# 警告：梯度范数过大 16.65，跳过此次更新
# 警告：梯度范数过大 11.39，跳过此次更新
# 警告：梯度范数过大 16.29，跳过此次更新
# 警告：梯度范数过大 23.36，跳过此次更新
# 警告：梯度范数过大 16.01，跳过此次更新
# 警告：梯度范数过大 14.96，跳过此次更新
# 警告：梯度范数过大 15.57，跳过此次更新
# 警告：梯度范数过大 11.48，跳过此次更新
# 警告：梯度范数过大 20.23，跳过此次更新
# 警告：梯度范数过大 29.51，跳过此次更新
# 警告：梯度范数过大 25.78，跳过此次更新
# 警告：梯度范数过大 24.85，跳过此次更新
# 警告：梯度范数过大 18.28，跳过此次更新
# 警告：梯度范数过大 23.28，跳过此次更新
# 警告：梯度范数过大 17.35，跳过此次更新
# 警告：梯度范数过大 15.30，跳过此次更新
# 警告：梯度范数过大 11.79，跳过此次更新
# 警告：梯度范数过大 10.24，跳过此次更新
# 警告：梯度范数过大 13.37，跳过此次更新
# 警告：梯度范数过大 17.51，跳过此次更新
# 警告：梯度范数过大 12.96，跳过此次更新
# 警告：梯度范数过大 16.91，跳过此次更新
# 警告：梯度范数过大 12.66，跳过此次更新
# 警告：梯度范数过大 20.58，跳过此次更新
# 警告：梯度范数过大 14.59，跳过此次更新
# 警告：梯度范数过大 11.26，跳过此次更新
# 警告：梯度范数过大 11.66，跳过此次更新
# 警告：梯度范数过大 11.79，跳过此次更新
# 警告：梯度范数过大 10.24，跳过此次更新
# 警告：梯度范数过大 13.37，跳过此次更新
# 警告：梯度范数过大 17.51，跳过此次更新
# 警告：梯度范数过大 12.96，跳过此次更新
# 警告：梯度范数过大 16.91，跳过此次更新
# 警告：梯度范数过大 12.66，跳过此次更新
# 警告：梯度范数过大 20.58，跳过此次更新
# 警告：梯度范数过大 14.59，跳过此次更新
# 警告：梯度范数过大 11.26，跳过此次更新
# 警告：梯度范数过大 11.66，跳过此次更新
# 警告：梯度范数过大 11.26，跳过此次更新
# 警告：梯度范数过大 10.45，跳过此次更新
# 警告：梯度范数过大 11.67，跳过此次更新
# 警告：梯度范数过大 10.07，跳过此次更新
# 警告：梯度范数过大 16.48，跳过此次更新
# 警告：梯度范数过大 16.28，跳过此次更新
# 警告：梯度范数过大 13.48，跳过此次更新
# 警告：梯度范数过大 12.23，跳过此次更新
# 警告：梯度范数过大 11.42，跳过此次更新
# 警告：梯度范数过大 11.26，跳过此次更新
# 警告：梯度范数过大 10.45，跳过此次更新
# 警告：梯度范数过大 11.67，跳过此次更新
# 警告：梯度范数过大 10.07，跳过此次更新
# 警告：梯度范数过大 16.48，跳过此次更新
# 警告：梯度范数过大 16.28，跳过此次更新
# 警告：梯度范数过大 13.48，跳过此次更新
# 警告：梯度范数过大 12.23，跳过此次更新
# 警告：梯度范数过大 11.42，跳过此次更新
# 警告：梯度范数过大 19.32，跳过此次更新
# 警告：梯度范数过大 21.33，跳过此次更新
# 警告：梯度范数过大 18.50，跳过此次更新
# 警告：梯度范数过大 16.05，跳过此次更新
# 警告：梯度范数过大 19.90，跳过此次更新
# 警告：梯度范数过大 12.40，跳过此次更新
# 警告：梯度范数过大 19.02，跳过此次更新
# 警告：梯度范数过大 24.47，跳过此次更新
# 警告：梯度范数过大 14.99，跳过此次更新
# 警告：梯度范数过大 18.16，跳过此次更新
# 警告：梯度范数过大 16.04，跳过此次更新
# 警告：梯度范数过大 17.14，跳过此次更新
# 警告：梯度范数过大 15.61，跳过此次更新
# 警告：梯度范数过大 13.37，跳过此次更新
# 警告：梯度范数过大 16.23，跳过此次更新
# 警告：梯度范数过大 12.64，跳过此次更新
# 警告：梯度范数过大 20.28，跳过此次更新
# 警告：梯度范数过大 10.39，跳过此次更新
# 警告：梯度范数过大 15.11，跳过此次更新
# 警告：梯度范数过大 19.19，跳过此次更新
# 警告：梯度范数过大 19.32，跳过此次更新
# 警告：梯度范数过大 21.33，跳过此次更新
# 警告：梯度范数过大 18.50，跳过此次更新
# 警告：梯度范数过大 16.05，跳过此次更新
# 警告：梯度范数过大 19.90，跳过此次更新
# 警告：梯度范数过大 12.40，跳过此次更新
# 警告：梯度范数过大 19.02，跳过此次更新
# 警告：梯度范数过大 24.47，跳过此次更新
# 警告：梯度范数过大 14.99，跳过此次更新
# 警告：梯度范数过大 18.16，跳过此次更新
# 警告：梯度范数过大 16.04，跳过此次更新
# 警告：梯度范数过大 17.14，跳过此次更新
# 警告：梯度范数过大 15.61，跳过此次更新
# 警告：梯度范数过大 13.37，跳过此次更新
# 警告：梯度范数过大 16.23，跳过此次更新
# 警告：梯度范数过大 12.64，跳过此次更新
# 警告：梯度范数过大 20.28，跳过此次更新
# 警告：梯度范数过大 10.39，跳过此次更新
# 警告：梯度范数过大 15.11，跳过此次更新
# 警告：梯度范数过大 19.19，跳过此次更新
# 警告：梯度范数过大 14.31，跳过此次更新
# 警告：梯度范数过大 19.55，跳过此次更新
# 警告：梯度范数过大 16.68，跳过此次更新
# 警告：梯度范数过大 17.38，跳过此次更新
# 警告：梯度范数过大 18.99，跳过此次更新
# 警告：梯度范数过大 19.23，跳过此次更新
# 警告：梯度范数过大 12.81，跳过此次更新
# 警告：梯度范数过大 17.58，跳过此次更新
# 警告：梯度范数过大 14.72，跳过此次更新
# 警告：梯度范数过大 18.41，跳过此次更新
# 警告：梯度范数过大 16.02，跳过此次更新
# 警告：梯度范数过大 20.37，跳过此次更新
# 警告：梯度范数过大 21.13，跳过此次更新
# 警告：梯度范数过大 14.71，跳过此次更新
# 警告：梯度范数过大 17.82，跳过此次更新
# 警告：梯度范数过大 18.98，跳过此次更新
# 警告：梯度范数过大 17.23，跳过此次更新
# 警告：梯度范数过大 14.48，跳过此次更新
# 警告：梯度范数过大 23.51，跳过此次更新
# 警告：梯度范数过大 16.08，跳过此次更新
# 警告：梯度范数过大 14.31，跳过此次更新
# 警告：梯度范数过大 19.55，跳过此次更新
# 警告：梯度范数过大 16.68，跳过此次更新
# 警告：梯度范数过大 17.38，跳过此次更新
# 警告：梯度范数过大 18.99，跳过此次更新
# 警告：梯度范数过大 19.23，跳过此次更新
# 警告：梯度范数过大 12.81，跳过此次更新
# 警告：梯度范数过大 17.58，跳过此次更新
# 警告：梯度范数过大 14.72，跳过此次更新
# 警告：梯度范数过大 18.41，跳过此次更新
# 警告：梯度范数过大 16.02，跳过此次更新
# 警告：梯度范数过大 20.37，跳过此次更新
# 警告：梯度范数过大 21.13，跳过此次更新
# 警告：梯度范数过大 14.71，跳过此次更新
# 警告：梯度范数过大 17.82，跳过此次更新
# 警告：梯度范数过大 18.98，跳过此次更新
# 警告：梯度范数过大 17.23，跳过此次更新
# 警告：梯度范数过大 14.48，跳过此次更新
# 警告：梯度范数过大 23.51，跳过此次更新
# 警告：梯度范数过大 16.08，跳过此次更新
# 警告：梯度范数过大 17.04，跳过此次更新
# 警告：梯度范数过大 18.89，跳过此次更新
# 警告：梯度范数过大 10.60，跳过此次更新
# 警告：梯度范数过大 15.77，跳过此次更新
# 警告：梯度范数过大 16.84，跳过此次更新
# 警告：梯度范数过大 18.84，跳过此次更新
# 警告：梯度范数过大 19.21，跳过此次更新
# 警告：梯度范数过大 13.66，跳过此次更新
# 警告：梯度范数过大 21.30，跳过此次更新
# 警告：梯度范数过大 19.65，跳过此次更新
# 警告：梯度范数过大 16.12，跳过此次更新
# 警告：梯度范数过大 11.31，跳过此次更新
# 警告：梯度范数过大 15.89，跳过此次更新
# 警告：梯度范数过大 16.96，跳过此次更新
# 警告：梯度范数过大 18.23，跳过此次更新
# 警告：梯度范数过大 13.45，跳过此次更新
# 警告：梯度范数过大 14.20，跳过此次更新
# 警告：梯度范数过大 13.54，跳过此次更新
# 警告：梯度范数过大 16.31，跳过此次更新
# 警告：梯度范数过大 13.56，跳过此次更新
# 警告：梯度范数过大 17.43，跳过此次更新
# 警告：梯度范数过大 17.04，跳过此次更新
# 警告：梯度范数过大 18.89，跳过此次更新
# 警告：梯度范数过大 10.60，跳过此次更新
# 警告：梯度范数过大 15.77，跳过此次更新
# 警告：梯度范数过大 16.84，跳过此次更新
# 警告：梯度范数过大 18.84，跳过此次更新
# 警告：梯度范数过大 19.21，跳过此次更新
# 警告：梯度范数过大 13.66，跳过此次更新
# 警告：梯度范数过大 21.30，跳过此次更新
# 警告：梯度范数过大 19.65，跳过此次更新
# 警告：梯度范数过大 16.12，跳过此次更新
# 警告：梯度范数过大 11.31，跳过此次更新
# 警告：梯度范数过大 15.89，跳过此次更新
# 警告：梯度范数过大 16.96，跳过此次更新
# 警告：梯度范数过大 18.23，跳过此次更新
# 警告：梯度范数过大 13.45，跳过此次更新
# 警告：梯度范数过大 14.20，跳过此次更新
# 警告：梯度范数过大 13.54，跳过此次更新
# 警告：梯度范数过大 16.31，跳过此次更新
# 警告：梯度范数过大 13.56，跳过此次更新
# 警告：梯度范数过大 17.43，跳过此次更新
# 警告：梯度范数过大 10.12，跳过此次更新
# 警告：梯度范数过大 16.72，跳过此次更新
# 警告：梯度范数过大 12.55，跳过此次更新
# 警告：梯度范数过大 13.08，跳过此次更新
# 警告：梯度范数过大 12.51，跳过此次更新
# 警告：梯度范数过大 14.15，跳过此次更新
# 警告：梯度范数过大 15.81，跳过此次更新
# 警告：梯度范数过大 19.32，跳过此次更新
# 警告：梯度范数过大 15.43，跳过此次更新
# 警告：梯度范数过大 16.45，跳过此次更新
# 警告：梯度范数过大 16.04，跳过此次更新
# 警告：梯度范数过大 22.47，跳过此次更新
# 警告：梯度范数过大 15.07，跳过此次更新
# 警告：梯度范数过大 19.48，跳过此次更新
# 警告：梯度范数过大 19.83，跳过此次更新
# 警告：梯度范数过大 16.57，跳过此次更新
# 警告：梯度范数过大 18.12，跳过此次更新
# 警告：梯度范数过大 16.09，跳过此次更新
# 警告：梯度范数过大 14.18，跳过此次更新
# 警告：梯度范数过大 15.40，跳过此次更新
# 警告：梯度范数过大 16.70，跳过此次更新
# 警告：梯度范数过大 10.12，跳过此次更新
# 警告：梯度范数过大 16.72，跳过此次更新
# 警告：梯度范数过大 12.55，跳过此次更新
# 警告：梯度范数过大 13.08，跳过此次更新
# 警告：梯度范数过大 12.51，跳过此次更新
# 警告：梯度范数过大 14.15，跳过此次更新
# 警告：梯度范数过大 15.81，跳过此次更新
# 警告：梯度范数过大 19.32，跳过此次更新
# 警告：梯度范数过大 15.43，跳过此次更新
# 警告：梯度范数过大 16.45，跳过此次更新
# 警告：梯度范数过大 16.04，跳过此次更新
# 警告：梯度范数过大 22.47，跳过此次更新
# 警告：梯度范数过大 15.07，跳过此次更新
# 警告：梯度范数过大 19.48，跳过此次更新
# 警告：梯度范数过大 19.83，跳过此次更新
# 警告：梯度范数过大 16.57，跳过此次更新
# 警告：梯度范数过大 18.12，跳过此次更新
# 警告：梯度范数过大 16.09，跳过此次更新
# 警告：梯度范数过大 14.18，跳过此次更新
# 警告：梯度范数过大 15.40，跳过此次更新
# 警告：梯度范数过大 16.70，跳过此次更新
# 警告：梯度范数过大 15.29，跳过此次更新
# 警告：梯度范数过大 16.12，跳过此次更新
# 警告：梯度范数过大 15.84，跳过此次更新
# 警告：梯度范数过大 15.28，跳过此次更新
# 警告：梯度范数过大 12.43，跳过此次更新
# 警告：梯度范数过大 16.60，跳过此次更新
# 警告：梯度范数过大 14.34，跳过此次更新
# 警告：梯度范数过大 18.12，跳过此次更新
# 警告：梯度范数过大 14.96，跳过此次更新
# 警告：梯度范数过大 17.77，跳过此次更新
# 警告：梯度范数过大 15.49，跳过此次更新
# 警告：梯度范数过大 19.26，跳过此次更新
# 警告：梯度范数过大 20.28，跳过此次更新
# 警告：梯度范数过大 24.79，跳过此次更新
# 警告：梯度范数过大 19.12，跳过此次更新
# 警告：梯度范数过大 21.52，跳过此次更新
# 警告：梯度范数过大 14.92，跳过此次更新
# 警告：梯度范数过大 17.21，跳过此次更新
# 警告：梯度范数过大 12.82，跳过此次更新
# 警告：梯度范数过大 12.37，跳过此次更新
# 警告：梯度范数过大 15.29，跳过此次更新
# 警告：梯度范数过大 16.12，跳过此次更新
# 警告：梯度范数过大 15.84，跳过此次更新
# 警告：梯度范数过大 15.28，跳过此次更新
# 警告：梯度范数过大 12.43，跳过此次更新
# 警告：梯度范数过大 16.60，跳过此次更新
# 警告：梯度范数过大 14.34，跳过此次更新
# 警告：梯度范数过大 18.12，跳过此次更新
# 警告：梯度范数过大 14.96，跳过此次更新
# 警告：梯度范数过大 17.77，跳过此次更新
# 警告：梯度范数过大 15.49，跳过此次更新
# 警告：梯度范数过大 19.26，跳过此次更新
# 警告：梯度范数过大 20.28，跳过此次更新
# 警告：梯度范数过大 24.79，跳过此次更新
# 警告：梯度范数过大 19.12，跳过此次更新
# 警告：梯度范数过大 21.52，跳过此次更新
# 警告：梯度范数过大 14.92，跳过此次更新
# 警告：梯度范数过大 17.21，跳过此次更新
# 警告：梯度范数过大 12.82，跳过此次更新
# 警告：梯度范数过大 12.37，跳过此次更新
# 警告：梯度范数过大 21.75，跳过此次更新
# 警告：梯度范数过大 17.64，跳过此次更新
# 警告：梯度范数过大 13.11，跳过此次更新
# 警告：梯度范数过大 18.72，跳过此次更新
# 警告：梯度范数过大 21.28，跳过此次更新
# 警告：梯度范数过大 20.46，跳过此次更新
# 警告：梯度范数过大 19.65，跳过此次更新
# 警告：梯度范数过大 15.66，跳过此次更新
# 警告：梯度范数过大 16.77，跳过此次更新
# 警告：梯度范数过大 15.53，跳过此次更新
# 警告：梯度范数过大 18.61，跳过此次更新
# 警告：梯度范数过大 15.85，跳过此次更新
# 警告：梯度范数过大 21.18，跳过此次更新
# 警告：梯度范数过大 15.78，跳过此次更新
# 警告：梯度范数过大 16.47，跳过此次更新
# 警告：梯度范数过大 14.95，跳过此次更新
# 警告：梯度范数过大 16.63，跳过此次更新
# 警告：梯度范数过大 17.86，跳过此次更新
# 警告：梯度范数过大 14.81，跳过此次更新
# 警告：梯度范数过大 16.99，跳过此次更新
# 警告：梯度范数过大 10.40，跳过此次更新
# 警告：梯度范数过大 21.75，跳过此次更新
# 警告：梯度范数过大 17.64，跳过此次更新
# 警告：梯度范数过大 13.11，跳过此次更新
# 警告：梯度范数过大 18.72，跳过此次更新
# 警告：梯度范数过大 21.28，跳过此次更新
# 警告：梯度范数过大 20.46，跳过此次更新
# 警告：梯度范数过大 19.65，跳过此次更新
# 警告：梯度范数过大 15.66，跳过此次更新
# 警告：梯度范数过大 16.77，跳过此次更新
# 警告：梯度范数过大 15.53，跳过此次更新
# 警告：梯度范数过大 18.61，跳过此次更新
# 警告：梯度范数过大 15.85，跳过此次更新
# 警告：梯度范数过大 21.18，跳过此次更新
# 警告：梯度范数过大 15.78，跳过此次更新
# 警告：梯度范数过大 16.47，跳过此次更新
# 警告：梯度范数过大 14.95，跳过此次更新
# 警告：梯度范数过大 16.63，跳过此次更新
# 警告：梯度范数过大 17.86，跳过此次更新
# 警告：梯度范数过大 14.81，跳过此次更新
# 警告：梯度范数过大 16.99，跳过此次更新
# 警告：梯度范数过大 10.40，跳过此次更新
# 警告：梯度范数过大 16.45，跳过此次更新
# 警告：梯度范数过大 16.09，跳过此次更新
# 警告：梯度范数过大 17.41，跳过此次更新
# 警告：梯度范数过大 16.80，跳过此次更新
# 警告：梯度范数过大 17.93，跳过此次更新
# 警告：梯度范数过大 14.95，跳过此次更新
# 警告：梯度范数过大 12.33，跳过此次更新
# 警告：梯度范数过大 20.55，跳过此次更新
# 警告：梯度范数过大 17.33，跳过此次更新
# 警告：梯度范数过大 15.64，跳过此次更新
# 警告：梯度范数过大 13.83，跳过此次更新
# 警告：梯度范数过大 11.70，跳过此次更新
# 警告：梯度范数过大 18.70，跳过此次更新
# 警告：梯度范数过大 12.94，跳过此次更新
# 警告：梯度范数过大 14.91，跳过此次更新
# 警告：梯度范数过大 18.85，跳过此次更新
# 警告：梯度范数过大 16.58，跳过此次更新
# 警告：梯度范数过大 18.43，跳过此次更新
# 警告：梯度范数过大 15.14，跳过此次更新
# 警告：梯度范数过大 16.55，跳过此次更新
# 警告：梯度范数过大 15.79，跳过此次更新
# 警告：梯度范数过大 16.45，跳过此次更新
# 警告：梯度范数过大 16.09，跳过此次更新
# 警告：梯度范数过大 17.41，跳过此次更新
# 警告：梯度范数过大 16.80，跳过此次更新
# 警告：梯度范数过大 17.93，跳过此次更新
# 警告：梯度范数过大 14.95，跳过此次更新
# 警告：梯度范数过大 12.33，跳过此次更新
# 警告：梯度范数过大 20.55，跳过此次更新
# 警告：梯度范数过大 17.33，跳过此次更新
# 警告：梯度范数过大 15.64，跳过此次更新
# 警告：梯度范数过大 13.83，跳过此次更新
# 警告：梯度范数过大 11.70，跳过此次更新
# 警告：梯度范数过大 18.70，跳过此次更新
# 警告：梯度范数过大 12.94，跳过此次更新
# 警告：梯度范数过大 14.91，跳过此次更新
# 警告：梯度范数过大 18.85，跳过此次更新
# 警告：梯度范数过大 16.58，跳过此次更新
# 警告：梯度范数过大 18.43，跳过此次更新
# 警告：梯度范数过大 15.14，跳过此次更新
# 警告：梯度范数过大 16.55，跳过此次更新
# 警告：梯度范数过大 15.79，跳过此次更新
# 警告：梯度范数过大 20.20，跳过此次更新
# 警告：梯度范数过大 21.23，跳过此次更新
# 警告：梯度范数过大 16.21，跳过此次更新
# 警告：梯度范数过大 20.94，跳过此次更新
# 警告：梯度范数过大 14.36，跳过此次更新
# 警告：梯度范数过大 15.13，跳过此次更新
# 警告：梯度范数过大 15.93，跳过此次更新
# 警告：梯度范数过大 13.09，跳过此次更新
# 警告：梯度范数过大 17.32，跳过此次更新
# 警告：梯度范数过大 14.64，跳过此次更新
# 警告：梯度范数过大 19.14，跳过此次更新
# 警告：梯度范数过大 12.27，跳过此次更新
# 警告：梯度范数过大 15.33，跳过此次更新
# 警告：梯度范数过大 13.87，跳过此次更新
# 警告：梯度范数过大 15.19，跳过此次更新
# 警告：梯度范数过大 17.34，跳过此次更新
# 警告：梯度范数过大 19.09，跳过此次更新
# 警告：梯度范数过大 18.67，跳过此次更新
# 警告：梯度范数过大 14.65，跳过此次更新
# 警告：梯度范数过大 20.18，跳过此次更新
# 警告：梯度范数过大 20.20，跳过此次更新
# 警告：梯度范数过大 21.23，跳过此次更新
# 警告：梯度范数过大 16.21，跳过此次更新
# 警告：梯度范数过大 20.94，跳过此次更新
# 警告：梯度范数过大 14.36，跳过此次更新
# 警告：梯度范数过大 15.13，跳过此次更新
# 警告：梯度范数过大 15.93，跳过此次更新
# 警告：梯度范数过大 13.09，跳过此次更新
# 警告：梯度范数过大 17.32，跳过此次更新
# 警告：梯度范数过大 14.64，跳过此次更新
# 警告：梯度范数过大 19.14，跳过此次更新
# 警告：梯度范数过大 12.27，跳过此次更新
# 警告：梯度范数过大 15.33，跳过此次更新
# 警告：梯度范数过大 13.87，跳过此次更新
# 警告：梯度范数过大 15.19，跳过此次更新
# 警告：梯度范数过大 17.34，跳过此次更新
# 警告：梯度范数过大 19.09，跳过此次更新
# 警告：梯度范数过大 18.67，跳过此次更新
# 警告：梯度范数过大 14.65，跳过此次更新
# 警告：梯度范数过大 20.18，跳过此次更新
# 警告：梯度范数过大 12.81，跳过此次更新
# 警告：梯度范数过大 20.01，跳过此次更新
# 警告：梯度范数过大 15.03，跳过此次更新
# 警告：梯度范数过大 14.26，跳过此次更新
# 警告：梯度范数过大 19.42，跳过此次更新
# 警告：梯度范数过大 16.04，跳过此次更新
# 警告：梯度范数过大 18.04，跳过此次更新
# 警告：梯度范数过大 18.56，跳过此次更新
# 警告：梯度范数过大 13.84，跳过此次更新
# 警告：梯度范数过大 17.69，跳过此次更新
# 警告：梯度范数过大 18.77，跳过此次更新
# 警告：梯度范数过大 22.18，跳过此次更新
# 警告：梯度范数过大 13.31，跳过此次更新
# 警告：梯度范数过大 17.97，跳过此次更新
# 警告：梯度范数过大 16.07，跳过此次更新
# 警告：梯度范数过大 19.62，跳过此次更新
# 警告：梯度范数过大 21.06，跳过此次更新
# 警告：梯度范数过大 14.16，跳过此次更新
# 警告：梯度范数过大 18.11，跳过此次更新
# 警告：梯度范数过大 14.77，跳过此次更新
# 警告：梯度范数过大 12.81，跳过此次更新
# 警告：梯度范数过大 20.01，跳过此次更新
# 警告：梯度范数过大 15.03，跳过此次更新
# 警告：梯度范数过大 14.26，跳过此次更新
# 警告：梯度范数过大 19.42，跳过此次更新
# 警告：梯度范数过大 16.04，跳过此次更新
# 警告：梯度范数过大 18.04，跳过此次更新
# 警告：梯度范数过大 18.56，跳过此次更新
# 警告：梯度范数过大 13.84，跳过此次更新
# 警告：梯度范数过大 17.69，跳过此次更新
# 警告：梯度范数过大 18.77，跳过此次更新
# 警告：梯度范数过大 22.18，跳过此次更新
# 警告：梯度范数过大 13.31，跳过此次更新
# 警告：梯度范数过大 17.97，跳过此次更新
# 警告：梯度范数过大 16.07，跳过此次更新
# 警告：梯度范数过大 19.62，跳过此次更新
# 警告：梯度范数过大 21.06，跳过此次更新
# 警告：梯度范数过大 14.16，跳过此次更新
# 警告：梯度范数过大 18.11，跳过此次更新
# 警告：梯度范数过大 14.77，跳过此次更新
# 警告：梯度范数过大 20.46，跳过此次更新
# 警告：梯度范数过大 14.61，跳过此次更新
# 警告：梯度范数过大 15.09，跳过此次更新
# 警告：梯度范数过大 11.62，跳过此次更新
# 警告：梯度范数过大 14.64，跳过此次更新
# 警告：梯度范数过大 10.21，跳过此次更新
# 警告：梯度范数过大 14.62，跳过此次更新
# 警告：梯度范数过大 15.56，跳过此次更新
# 警告：梯度范数过大 13.38，跳过此次更新
# 警告：梯度范数过大 15.19，跳过此次更新
# 警告：梯度范数过大 17.07，跳过此次更新
# 警告：梯度范数过大 18.68，跳过此次更新
# 警告：梯度范数过大 17.65，跳过此次更新
# 警告：梯度范数过大 18.54，跳过此次更新
# 警告：梯度范数过大 17.03，跳过此次更新
# 警告：梯度范数过大 18.20，跳过此次更新
# 警告：梯度范数过大 15.21，跳过此次更新
# 警告：梯度范数过大 16.14，跳过此次更新
# 警告：梯度范数过大 15.54，跳过此次更新
# 警告：梯度范数过大 15.52，跳过此次更新
# 警告：梯度范数过大 20.46，跳过此次更新
# 警告：梯度范数过大 14.61，跳过此次更新
# 警告：梯度范数过大 15.09，跳过此次更新
# 警告：梯度范数过大 11.62，跳过此次更新
# 警告：梯度范数过大 14.64，跳过此次更新
# 警告：梯度范数过大 10.21，跳过此次更新
# 警告：梯度范数过大 14.62，跳过此次更新
# 警告：梯度范数过大 15.56，跳过此次更新
# 警告：梯度范数过大 13.38，跳过此次更新
# 警告：梯度范数过大 15.19，跳过此次更新
# 警告：梯度范数过大 17.07，跳过此次更新
# 警告：梯度范数过大 18.68，跳过此次更新
# 警告：梯度范数过大 17.65，跳过此次更新
# 警告：梯度范数过大 18.54，跳过此次更新
# 警告：梯度范数过大 17.03，跳过此次更新
# 警告：梯度范数过大 18.20，跳过此次更新
# 警告：梯度范数过大 15.21，跳过此次更新
# 警告：梯度范数过大 16.14，跳过此次更新
# 警告：梯度范数过大 15.54，跳过此次更新
# 警告：梯度范数过大 15.52，跳过此次更新
# 警告：梯度范数过大 16.27，跳过此次更新
# 警告：梯度范数过大 15.61，跳过此次更新
# 警告：梯度范数过大 17.54，跳过此次更新
# 警告：梯度范数过大 11.92，跳过此次更新
# 警告：梯度范数过大 11.37，跳过此次更新
# 警告：梯度范数过大 14.74，跳过此次更新
# 警告：梯度范数过大 18.24，跳过此次更新
# 警告：梯度范数过大 16.12，跳过此次更新
# 警告：梯度范数过大 12.79，跳过此次更新
# 警告：梯度范数过大 16.58，跳过此次更新
# 警告：梯度范数过大 13.50，跳过此次更新
# 警告：梯度范数过大 15.16，跳过此次更新
# 警告：梯度范数过大 18.98，跳过此次更新
# 警告：梯度范数过大 17.06，跳过此次更新
# 警告：梯度范数过大 17.55，跳过此次更新
# 警告：梯度范数过大 19.78，跳过此次更新
# 警告：梯度范数过大 19.16，跳过此次更新
# 警告：梯度范数过大 14.85，跳过此次更新
# 警告：梯度范数过大 12.74，跳过此次更新
# 警告：梯度范数过大 20.88，跳过此次更新
# 警告：梯度范数过大 13.02，跳过此次更新
# 警告：梯度范数过大 16.27，跳过此次更新
# 警告：梯度范数过大 15.61，跳过此次更新
# 警告：梯度范数过大 17.54，跳过此次更新
# 警告：梯度范数过大 11.92，跳过此次更新
# 警告：梯度范数过大 11.37，跳过此次更新
# 警告：梯度范数过大 14.74，跳过此次更新
# 警告：梯度范数过大 18.24，跳过此次更新
# 警告：梯度范数过大 16.12，跳过此次更新
# 警告：梯度范数过大 12.79，跳过此次更新
# 警告：梯度范数过大 16.58，跳过此次更新
# 警告：梯度范数过大 13.50，跳过此次更新
# 警告：梯度范数过大 15.16，跳过此次更新
# 警告：梯度范数过大 18.98，跳过此次更新
# 警告：梯度范数过大 17.06，跳过此次更新
# 警告：梯度范数过大 17.55，跳过此次更新
# 警告：梯度范数过大 19.78，跳过此次更新
# 警告：梯度范数过大 19.16，跳过此次更新
# 警告：梯度范数过大 14.85，跳过此次更新
# 警告：梯度范数过大 12.74，跳过此次更新
# 警告：梯度范数过大 20.88，跳过此次更新
# 警告：梯度范数过大 13.02，跳过此次更新
# 警告：梯度范数过大 17.01，跳过此次更新
# 警告：梯度范数过大 16.54，跳过此次更新
# 警告：梯度范数过大 17.46，跳过此次更新
# 警告：梯度范数过大 18.78，跳过此次更新
# 警告：梯度范数过大 14.16，跳过此次更新
# 警告：梯度范数过大 19.15，跳过此次更新
# 警告：梯度范数过大 19.83，跳过此次更新
# 警告：梯度范数过大 12.86，跳过此次更新
# 警告：梯度范数过大 20.39，跳过此次更新
# 警告：梯度范数过大 18.76，跳过此次更新
# 警告：梯度范数过大 11.60，跳过此次更新
# 警告：梯度范数过大 16.07，跳过此次更新
# 警告：梯度范数过大 15.88，跳过此次更新
# 警告：梯度范数过大 14.45，跳过此次更新
# 警告：梯度范数过大 14.72，跳过此次更新
# 警告：梯度范数过大 23.25，跳过此次更新
# 警告：梯度范数过大 16.42，跳过此次更新
# 警告：梯度范数过大 12.03，跳过此次更新
# 警告：梯度范数过大 22.06，跳过此次更新
# 警告：梯度范数过大 13.28，跳过此次更新
# 警告：梯度范数过大 17.01，跳过此次更新
# 警告：梯度范数过大 16.54，跳过此次更新
# 警告：梯度范数过大 17.46，跳过此次更新
# 警告：梯度范数过大 18.78，跳过此次更新
# 警告：梯度范数过大 14.16，跳过此次更新
# 警告：梯度范数过大 19.15，跳过此次更新
# 警告：梯度范数过大 19.83，跳过此次更新
# 警告：梯度范数过大 12.86，跳过此次更新
# 警告：梯度范数过大 20.39，跳过此次更新
# 警告：梯度范数过大 18.76，跳过此次更新
# 警告：梯度范数过大 11.60，跳过此次更新
# 警告：梯度范数过大 16.07，跳过此次更新
# 警告：梯度范数过大 15.88，跳过此次更新
# 警告：梯度范数过大 14.45，跳过此次更新
# 警告：梯度范数过大 14.72，跳过此次更新
# 警告：梯度范数过大 23.25，跳过此次更新
# 警告：梯度范数过大 16.42，跳过此次更新
# 警告：梯度范数过大 12.03，跳过此次更新
# 警告：梯度范数过大 22.06，跳过此次更新
# 警告：梯度范数过大 13.28，跳过此次更新
# 警告：梯度范数过大 18.86，跳过此次更新
# 警告：梯度范数过大 17.05，跳过此次更新
# 警告：梯度范数过大 19.95，跳过此次更新
# 警告：梯度范数过大 13.27，跳过此次更新
# 警告：梯度范数过大 12.57，跳过此次更新
# 警告：梯度范数过大 15.65，跳过此次更新
# 警告：梯度范数过大 13.52，跳过此次更新
# 警告：梯度范数过大 14.43，跳过此次更新
# 警告：梯度范数过大 19.38，跳过此次更新
# 警告：梯度范数过大 19.01，跳过此次更新
# 警告：梯度范数过大 15.05，跳过此次更新
# 警告：梯度范数过大 17.21，跳过此次更新
# 警告：梯度范数过大 17.26，跳过此次更新
# 警告：梯度范数过大 19.03，跳过此次更新
# 警告：梯度范数过大 13.88，跳过此次更新
# 警告：梯度范数过大 14.09，跳过此次更新
# 警告：梯度范数过大 12.10，跳过此次更新
# 警告：梯度范数过大 18.40，跳过此次更新
# 警告：梯度范数过大 10.76，跳过此次更新
# 警告：梯度范数过大 18.31，跳过此次更新
# 警告：梯度范数过大 17.86，跳过此次更新
# 警告：梯度范数过大 18.86，跳过此次更新
# 警告：梯度范数过大 17.05，跳过此次更新
# 警告：梯度范数过大 19.95，跳过此次更新
# 警告：梯度范数过大 13.27，跳过此次更新
# 警告：梯度范数过大 12.57，跳过此次更新
# 警告：梯度范数过大 15.65，跳过此次更新
# 警告：梯度范数过大 13.52，跳过此次更新
# 警告：梯度范数过大 14.43，跳过此次更新
# 警告：梯度范数过大 19.38，跳过此次更新
# 警告：梯度范数过大 19.01，跳过此次更新
# 警告：梯度范数过大 15.05，跳过此次更新
# 警告：梯度范数过大 17.21，跳过此次更新
# 警告：梯度范数过大 17.26，跳过此次更新
# 警告：梯度范数过大 19.03，跳过此次更新
# 警告：梯度范数过大 13.88，跳过此次更新
# 警告：梯度范数过大 14.09，跳过此次更新
# 警告：梯度范数过大 12.10，跳过此次更新
# 警告：梯度范数过大 18.40，跳过此次更新
# 警告：梯度范数过大 10.76，跳过此次更新
# 警告：梯度范数过大 18.31，跳过此次更新
# 警告：梯度范数过大 17.86，跳过此次更新
# 警告：梯度范数过大 14.91，跳过此次更新
# 警告：梯度范数过大 17.43，跳过此次更新
# 警告：梯度范数过大 14.45，跳过此次更新
# 警告：梯度范数过大 21.83，跳过此次更新
# 警告：梯度范数过大 14.75，跳过此次更新
# 警告：梯度范数过大 20.84，跳过此次更新
# 警告：梯度范数过大 17.46，跳过此次更新
# 警告：梯度范数过大 15.36，跳过此次更新
# 警告：梯度范数过大 16.25，跳过此次更新
# 警告：梯度范数过大 15.27，跳过此次更新
# 警告：梯度范数过大 19.83，跳过此次更新
# 警告：梯度范数过大 13.44，跳过此次更新
# 警告：梯度范数过大 12.08，跳过此次更新
# 警告：梯度范数过大 16.83，跳过此次更新
# 警告：梯度范数过大 12.98，跳过此次更新
# 警告：梯度范数过大 18.55，跳过此次更新
# 警告：梯度范数过大 12.45，跳过此次更新
# 警告：梯度范数过大 13.54，跳过此次更新
# 警告：梯度范数过大 19.16，跳过此次更新
# 警告：梯度范数过大 13.64，跳过此次更新
# 警告：梯度范数过大 14.91，跳过此次更新
# 警告：梯度范数过大 17.43，跳过此次更新
# 警告：梯度范数过大 14.45，跳过此次更新
# 警告：梯度范数过大 21.83，跳过此次更新
# 警告：梯度范数过大 14.75，跳过此次更新
# 警告：梯度范数过大 20.84，跳过此次更新
# 警告：梯度范数过大 17.46，跳过此次更新
# 警告：梯度范数过大 15.36，跳过此次更新
# 警告：梯度范数过大 16.25，跳过此次更新
# 警告：梯度范数过大 15.27，跳过此次更新
# 警告：梯度范数过大 19.83，跳过此次更新
# 警告：梯度范数过大 13.44，跳过此次更新
# 警告：梯度范数过大 12.08，跳过此次更新
# 警告：梯度范数过大 16.83，跳过此次更新
# 警告：梯度范数过大 12.98，跳过此次更新
# 警告：梯度范数过大 18.55，跳过此次更新
# 警告：梯度范数过大 12.45，跳过此次更新
# 警告：梯度范数过大 13.54，跳过此次更新
# 警告：梯度范数过大 19.16，跳过此次更新
# 警告：梯度范数过大 13.64，跳过此次更新
# 警告：梯度范数过大 17.41，跳过此次更新
# 警告：梯度范数过大 19.18，跳过此次更新
# 警告：梯度范数过大 16.43，跳过此次更新
# 警告：梯度范数过大 14.64，跳过此次更新
# 警告：梯度范数过大 13.31，跳过此次更新
# 警告：梯度范数过大 15.24，跳过此次更新
# 警告：梯度范数过大 18.54，跳过此次更新
# 警告：梯度范数过大 17.54，跳过此次更新
# 警告：梯度范数过大 19.10，跳过此次更新
# 警告：梯度范数过大 20.48，跳过此次更新
# 警告：梯度范数过大 14.62，跳过此次更新
# 警告：梯度范数过大 14.46，跳过此次更新
# 警告：梯度范数过大 14.55，跳过此次更新
# 警告：梯度范数过大 13.52，跳过此次更新
# 警告：梯度范数过大 16.60，跳过此次更新
# 警告：梯度范数过大 21.52，跳过此次更新
# 警告：梯度范数过大 14.83，跳过此次更新
# 警告：梯度范数过大 11.60，跳过此次更新
# 警告：梯度范数过大 20.28，跳过此次更新
# 警告：梯度范数过大 17.41，跳过此次更新
# 警告：梯度范数过大 19.18，跳过此次更新
# 警告：梯度范数过大 16.43，跳过此次更新
# 警告：梯度范数过大 14.64，跳过此次更新
# 警告：梯度范数过大 13.31，跳过此次更新
# 警告：梯度范数过大 15.24，跳过此次更新
# 警告：梯度范数过大 18.54，跳过此次更新
# 警告：梯度范数过大 17.54，跳过此次更新
# 警告：梯度范数过大 19.10，跳过此次更新
# 警告：梯度范数过大 20.48，跳过此次更新
# 警告：梯度范数过大 14.62，跳过此次更新
# 警告：梯度范数过大 14.46，跳过此次更新
# 警告：梯度范数过大 14.55，跳过此次更新
# 警告：梯度范数过大 13.52，跳过此次更新
# 警告：梯度范数过大 16.60，跳过此次更新
# 警告：梯度范数过大 21.52，跳过此次更新
# 警告：梯度范数过大 14.83，跳过此次更新
# 警告：梯度范数过大 11.60，跳过此次更新
# 警告：梯度范数过大 20.28，跳过此次更新
# 警告：梯度范数过大 15.21，跳过此次更新
# 警告：梯度范数过大 15.04，跳过此次更新
# 警告：梯度范数过大 16.93，跳过此次更新
# 警告：梯度范数过大 16.75，跳过此次更新
# 警告：梯度范数过大 17.92，跳过此次更新
# 警告：梯度范数过大 17.35，跳过此次更新
# 警告：梯度范数过大 18.25，跳过此次更新
# 警告：梯度范数过大 19.52，跳过此次更新
# 警告：梯度范数过大 18.34，跳过此次更新
# 警告：梯度范数过大 13.65，跳过此次更新
# 警告：梯度范数过大 15.89，跳过此次更新
# 警告：梯度范数过大 14.98，跳过此次更新
# 警告：梯度范数过大 15.35，跳过此次更新
# 警告：梯度范数过大 15.80，跳过此次更新
# 警告：梯度范数过大 16.89，跳过此次更新
# 警告：梯度范数过大 17.99，跳过此次更新
# 警告：梯度范数过大 12.95，跳过此次更新
# 警告：梯度范数过大 19.28，跳过此次更新
# 警告：梯度范数过大 14.51，跳过此次更新
# 警告：梯度范数过大 17.68，跳过此次更新
# 警告：梯度范数过大 15.21，跳过此次更新
# 警告：梯度范数过大 15.04，跳过此次更新
# 警告：梯度范数过大 16.93，跳过此次更新
# 警告：梯度范数过大 16.75，跳过此次更新
# 警告：梯度范数过大 17.92，跳过此次更新
# 警告：梯度范数过大 17.35，跳过此次更新
# 警告：梯度范数过大 18.25，跳过此次更新
# 警告：梯度范数过大 19.52，跳过此次更新
# 警告：梯度范数过大 18.34，跳过此次更新
# 警告：梯度范数过大 13.65，跳过此次更新
# 警告：梯度范数过大 15.89，跳过此次更新
# 警告：梯度范数过大 14.98，跳过此次更新
# 警告：梯度范数过大 15.35，跳过此次更新
# 警告：梯度范数过大 15.80，跳过此次更新
# 警告：梯度范数过大 16.89，跳过此次更新
# 警告：梯度范数过大 17.99，跳过此次更新
# 警告：梯度范数过大 12.95，跳过此次更新
# 警告：梯度范数过大 19.28，跳过此次更新
# 警告：梯度范数过大 14.51，跳过此次更新
# 警告：梯度范数过大 17.68，跳过此次更新
# 警告：梯度范数过大 18.79，跳过此次更新
# 警告：梯度范数过大 15.66，跳过此次更新
# 警告：梯度范数过大 17.23，跳过此次更新
# 警告：梯度范数过大 11.98，跳过此次更新
# 警告：梯度范数过大 17.00，跳过此次更新
# 警告：梯度范数过大 16.92，跳过此次更新
# 警告：梯度范数过大 14.22，跳过此次更新
# 警告：梯度范数过大 19.09，跳过此次更新
# 警告：梯度范数过大 24.33，跳过此次更新
# 警告：梯度范数过大 15.17，跳过此次更新
# 警告：梯度范数过大 18.45，跳过此次更新
# 警告：梯度范数过大 17.85，跳过此次更新
# 警告：梯度范数过大 10.81，跳过此次更新
# 警告：梯度范数过大 20.50，跳过此次更新
# 警告：梯度范数过大 14.99，跳过此次更新
# 警告：梯度范数过大 13.96，跳过此次更新
# 警告：梯度范数过大 15.91，跳过此次更新
# 警告：梯度范数过大 16.87，跳过此次更新
# 警告：梯度范数过大 14.14，跳过此次更新
# 警告：梯度范数过大 11.77，跳过此次更新
# 警告：梯度范数过大 18.79，跳过此次更新
# 警告：梯度范数过大 15.66，跳过此次更新
# 警告：梯度范数过大 17.23，跳过此次更新
# 警告：梯度范数过大 11.98，跳过此次更新
# 警告：梯度范数过大 17.00，跳过此次更新
# 警告：梯度范数过大 16.92，跳过此次更新
# 警告：梯度范数过大 14.22，跳过此次更新
# 警告：梯度范数过大 19.09，跳过此次更新
# 警告：梯度范数过大 24.33，跳过此次更新
# 警告：梯度范数过大 15.17，跳过此次更新
# 警告：梯度范数过大 18.45，跳过此次更新
# 警告：梯度范数过大 17.85，跳过此次更新
# 警告：梯度范数过大 10.81，跳过此次更新
# 警告：梯度范数过大 20.50，跳过此次更新
# 警告：梯度范数过大 14.99，跳过此次更新
# 警告：梯度范数过大 13.96，跳过此次更新
# 警告：梯度范数过大 15.91，跳过此次更新
# 警告：梯度范数过大 16.87，跳过此次更新
# 警告：梯度范数过大 14.14，跳过此次更新
# 警告：梯度范数过大 11.77，跳过此次更新
# 警告：梯度范数过大 19.01，跳过此次更新
# 警告：梯度范数过大 23.03，跳过此次更新
# 警告：梯度范数过大 17.73，跳过此次更新
# 警告：梯度范数过大 17.70，跳过此次更新
# 警告：梯度范数过大 14.97，跳过此次更新
# 警告：梯度范数过大 13.23，跳过此次更新
# 警告：梯度范数过大 18.91，跳过此次更新
# 警告：梯度范数过大 18.31，跳过此次更新
# 警告：梯度范数过大 16.30，跳过此次更新
# 警告：梯度范数过大 15.63，跳过此次更新
# 警告：梯度范数过大 15.15，跳过此次更新
# 警告：梯度范数过大 15.16，跳过此次更新
# 警告：梯度范数过大 15.93，跳过此次更新
# 警告：梯度范数过大 15.58，跳过此次更新
# 警告：梯度范数过大 21.95，跳过此次更新
# 警告：梯度范数过大 17.36，跳过此次更新
# 警告：梯度范数过大 20.41，跳过此次更新
# 警告：梯度范数过大 14.46，跳过此次更新
# 警告：梯度范数过大 14.89，跳过此次更新
# 警告：梯度范数过大 12.72，跳过此次更新
# 警告：梯度范数过大 19.01，跳过此次更新
# 警告：梯度范数过大 23.03，跳过此次更新
# 警告：梯度范数过大 17.73，跳过此次更新
# 警告：梯度范数过大 17.70，跳过此次更新
# 警告：梯度范数过大 14.97，跳过此次更新
# 警告：梯度范数过大 13.23，跳过此次更新
# 警告：梯度范数过大 18.91，跳过此次更新
# 警告：梯度范数过大 18.31，跳过此次更新
# 警告：梯度范数过大 16.30，跳过此次更新
# 警告：梯度范数过大 15.63，跳过此次更新
# 警告：梯度范数过大 15.15，跳过此次更新
# 警告：梯度范数过大 15.16，跳过此次更新
# 警告：梯度范数过大 15.93，跳过此次更新
# 警告：梯度范数过大 15.58，跳过此次更新
# 警告：梯度范数过大 21.95，跳过此次更新
# 警告：梯度范数过大 17.36，跳过此次更新
# 警告：梯度范数过大 20.41，跳过此次更新
# 警告：梯度范数过大 14.46，跳过此次更新
# 警告：梯度范数过大 14.89，跳过此次更新
# 警告：梯度范数过大 12.72，跳过此次更新
# 警告：梯度范数过大 17.89，跳过此次更新
# 警告：梯度范数过大 15.31，跳过此次更新
# 警告：梯度范数过大 20.93，跳过此次更新
# 警告：梯度范数过大 10.73，跳过此次更新
# 警告：梯度范数过大 17.00，跳过此次更新
# 警告：梯度范数过大 15.70，跳过此次更新
# 警告：梯度范数过大 18.52，跳过此次更新
# 警告：梯度范数过大 22.22，跳过此次更新
# 警告：梯度范数过大 19.55，跳过此次更新
# 警告：梯度范数过大 12.46，跳过此次更新
# 警告：梯度范数过大 16.22，跳过此次更新
# 警告：梯度范数过大 15.90，跳过此次更新
# 警告：梯度范数过大 17.35，跳过此次更新
# 警告：梯度范数过大 18.81，跳过此次更新
# 警告：梯度范数过大 17.90，跳过此次更新
# 警告：梯度范数过大 19.74，跳过此次更新
# 警告：梯度范数过大 12.47，跳过此次更新
# 警告：梯度范数过大 16.42，跳过此次更新
# 警告：梯度范数过大 18.15，跳过此次更新
# 警告：梯度范数过大 19.00，跳过此次更新
# 警告：梯度范数过大 17.89，跳过此次更新
# 警告：梯度范数过大 15.31，跳过此次更新
# 警告：梯度范数过大 20.93，跳过此次更新
# 警告：梯度范数过大 10.73，跳过此次更新
# 警告：梯度范数过大 17.00，跳过此次更新
# 警告：梯度范数过大 15.70，跳过此次更新
# 警告：梯度范数过大 18.52，跳过此次更新
# 警告：梯度范数过大 22.22，跳过此次更新
# 警告：梯度范数过大 19.55，跳过此次更新
# 警告：梯度范数过大 12.46，跳过此次更新
# 警告：梯度范数过大 16.22，跳过此次更新
# 警告：梯度范数过大 15.90，跳过此次更新
# 警告：梯度范数过大 17.35，跳过此次更新
# 警告：梯度范数过大 18.81，跳过此次更新
# 警告：梯度范数过大 17.90，跳过此次更新
# 警告：梯度范数过大 19.74，跳过此次更新
# 警告：梯度范数过大 12.47，跳过此次更新
# 警告：梯度范数过大 16.42，跳过此次更新
# 警告：梯度范数过大 18.15，跳过此次更新
# 警告：梯度范数过大 19.00，跳过此次更新
# 警告：梯度范数过大 11.22，跳过此次更新
# 警告：梯度范数过大 11.12，跳过此次更新
# 警告：梯度范数过大 12.09，跳过此次更新
# 警告：梯度范数过大 15.39，跳过此次更新
# 警告：梯度范数过大 16.20，跳过此次更新
# 警告：梯度范数过大 20.42，跳过此次更新
# 警告：梯度范数过大 15.92，跳过此次更新
# 警告：梯度范数过大 19.14，跳过此次更新
# 警告：梯度范数过大 10.98，跳过此次更新
# 警告：梯度范数过大 12.98，跳过此次更新
# 警告：梯度范数过大 10.80，跳过此次更新
# 警告：梯度范数过大 13.75，跳过此次更新
# 警告：梯度范数过大 19.19，跳过此次更新
# 警告：梯度范数过大 15.24，跳过此次更新
# 警告：梯度范数过大 16.44，跳过此次更新
# 警告：梯度范数过大 17.23，跳过此次更新
# 警告：梯度范数过大 19.57，跳过此次更新
# 警告：梯度范数过大 12.27，跳过此次更新
# 警告：梯度范数过大 20.42，跳过此次更新
# 警告：梯度范数过大 16.42，跳过此次更新
# 警告：梯度范数过大 11.22，跳过此次更新
# 警告：梯度范数过大 11.12，跳过此次更新
# 警告：梯度范数过大 12.09，跳过此次更新
# 警告：梯度范数过大 15.39，跳过此次更新
# 警告：梯度范数过大 16.20，跳过此次更新
# 警告：梯度范数过大 20.42，跳过此次更新
# 警告：梯度范数过大 15.92，跳过此次更新
# 警告：梯度范数过大 19.14，跳过此次更新
# 警告：梯度范数过大 10.98，跳过此次更新
# 警告：梯度范数过大 12.98，跳过此次更新
# 警告：梯度范数过大 10.80，跳过此次更新
# 警告：梯度范数过大 13.75，跳过此次更新
# 警告：梯度范数过大 19.19，跳过此次更新
# 警告：梯度范数过大 15.24，跳过此次更新
# 警告：梯度范数过大 16.44，跳过此次更新
# 警告：梯度范数过大 17.23，跳过此次更新
# 警告：梯度范数过大 19.57，跳过此次更新
# 警告：梯度范数过大 12.27，跳过此次更新
# 警告：梯度范数过大 20.42，跳过此次更新
# 警告：梯度范数过大 16.42，跳过此次更新
# 警告：梯度范数过大 18.92，跳过此次更新
# 警告：梯度范数过大 17.90，跳过此次更新
# 警告：梯度范数过大 14.78，跳过此次更新
# 警告：梯度范数过大 14.33，跳过此次更新
# 警告：梯度范数过大 20.67，跳过此次更新
# 警告：梯度范数过大 16.30，跳过此次更新
# 警告：梯度范数过大 14.07，跳过此次更新
# 警告：梯度范数过大 18.42，跳过此次更新
# 警告：梯度范数过大 15.27，跳过此次更新
# 警告：梯度范数过大 20.00，跳过此次更新
# 警告：梯度范数过大 17.25，跳过此次更新
# 警告：梯度范数过大 12.51，跳过此次更新
# 警告：梯度范数过大 13.65，跳过此次更新
# 警告：梯度范数过大 18.02，跳过此次更新
# 警告：梯度范数过大 15.15，跳过此次更新
# 警告：梯度范数过大 14.11，跳过此次更新
# 警告：梯度范数过大 22.67，跳过此次更新
# 警告：梯度范数过大 17.99，跳过此次更新
# 警告：梯度范数过大 16.25，跳过此次更新
# 警告：梯度范数过大 17.61，跳过此次更新
# 警告：梯度范数过大 15.40，跳过此次更新
# 警告：梯度范数过大 18.92，跳过此次更新
# 警告：梯度范数过大 17.90，跳过此次更新
# 警告：梯度范数过大 14.78，跳过此次更新
# 警告：梯度范数过大 14.33，跳过此次更新
# 警告：梯度范数过大 20.67，跳过此次更新
# 警告：梯度范数过大 16.30，跳过此次更新
# 警告：梯度范数过大 14.07，跳过此次更新
# 警告：梯度范数过大 18.42，跳过此次更新
# 警告：梯度范数过大 15.27，跳过此次更新
# 警告：梯度范数过大 20.00，跳过此次更新
# 警告：梯度范数过大 17.25，跳过此次更新
# 警告：梯度范数过大 12.51，跳过此次更新
# 警告：梯度范数过大 13.65，跳过此次更新
# 警告：梯度范数过大 18.02，跳过此次更新
# 警告：梯度范数过大 15.15，跳过此次更新
# 警告：梯度范数过大 14.11，跳过此次更新
# 警告：梯度范数过大 22.67，跳过此次更新
# 警告：梯度范数过大 17.99，跳过此次更新
# 警告：梯度范数过大 16.25，跳过此次更新
# 警告：梯度范数过大 17.61，跳过此次更新
# 警告：梯度范数过大 15.40，跳过此次更新
# 警告：梯度范数过大 18.20，跳过此次更新
# 警告：梯度范数过大 14.59，跳过此次更新
# 警告：梯度范数过大 12.21，跳过此次更新
# 警告：梯度范数过大 13.72，跳过此次更新
# 警告：梯度范数过大 16.55，跳过此次更新
# 警告：梯度范数过大 15.83，跳过此次更新
# 警告：梯度范数过大 16.80，跳过此次更新
# 警告：梯度范数过大 15.27，跳过此次更新
# 警告：梯度范数过大 16.50，跳过此次更新
# 警告：梯度范数过大 14.68，跳过此次更新
# 警告：梯度范数过大 15.74，跳过此次更新
# 警告：梯度范数过大 16.45，跳过此次更新
# 警告：梯度范数过大 17.19，跳过此次更新
# 警告：梯度范数过大 13.52，跳过此次更新
# 警告：梯度范数过大 18.27，跳过此次更新
# 警告：梯度范数过大 16.53，跳过此次更新
# 警告：梯度范数过大 19.31，跳过此次更新
# 警告：梯度范数过大 23.45，跳过此次更新
# 警告：梯度范数过大 19.61，跳过此次更新
# 警告：梯度范数过大 18.20，跳过此次更新
# 警告：梯度范数过大 14.59，跳过此次更新
# 警告：梯度范数过大 12.21，跳过此次更新
# 警告：梯度范数过大 13.72，跳过此次更新
# 警告：梯度范数过大 16.55，跳过此次更新
# 警告：梯度范数过大 15.83，跳过此次更新
# 警告：梯度范数过大 16.80，跳过此次更新
# 警告：梯度范数过大 15.27，跳过此次更新
# 警告：梯度范数过大 16.50，跳过此次更新
# 警告：梯度范数过大 14.68，跳过此次更新
# 警告：梯度范数过大 15.74，跳过此次更新
# 警告：梯度范数过大 16.45，跳过此次更新
# 警告：梯度范数过大 17.19，跳过此次更新
# 警告：梯度范数过大 13.52，跳过此次更新
# 警告：梯度范数过大 18.27，跳过此次更新
# 警告：梯度范数过大 16.53，跳过此次更新
# 警告：梯度范数过大 19.31，跳过此次更新
# 警告：梯度范数过大 23.45，跳过此次更新
# 警告：梯度范数过大 19.61，跳过此次更新
# 警告：梯度范数过大 14.83，跳过此次更新
# 警告：梯度范数过大 15.71，跳过此次更新
# 警告：梯度范数过大 17.71，跳过此次更新
# 警告：梯度范数过大 18.78，跳过此次更新
# 警告：梯度范数过大 18.56，跳过此次更新
# 警告：梯度范数过大 11.21，跳过此次更新
# 警告：梯度范数过大 18.05，跳过此次更新
# 警告：梯度范数过大 17.63，跳过此次更新
# 警告：梯度范数过大 15.35，跳过此次更新
# 警告：梯度范数过大 20.93，跳过此次更新
# 警告：梯度范数过大 14.91，跳过此次更新
# 警告：梯度范数过大 16.55，跳过此次更新
# 警告：梯度范数过大 20.78，跳过此次更新
# 警告：梯度范数过大 16.80，跳过此次更新
# 警告：梯度范数过大 19.03，跳过此次更新
# 警告：梯度范数过大 19.29，跳过此次更新
# 警告：梯度范数过大 15.26，跳过此次更新
# 警告：梯度范数过大 17.50，跳过此次更新
# 警告：梯度范数过大 22.56，跳过此次更新
# 警告：梯度范数过大 14.83，跳过此次更新
# 警告：梯度范数过大 15.71，跳过此次更新
# 警告：梯度范数过大 17.71，跳过此次更新
# 警告：梯度范数过大 18.78，跳过此次更新
# 警告：梯度范数过大 18.56，跳过此次更新
# 警告：梯度范数过大 11.21，跳过此次更新
# 警告：梯度范数过大 18.05，跳过此次更新
# 警告：梯度范数过大 17.63，跳过此次更新
# 警告：梯度范数过大 15.35，跳过此次更新
# 警告：梯度范数过大 20.93，跳过此次更新
# 警告：梯度范数过大 14.91，跳过此次更新
# 警告：梯度范数过大 16.55，跳过此次更新
# 警告：梯度范数过大 20.78，跳过此次更新
# 警告：梯度范数过大 16.80，跳过此次更新
# 警告：梯度范数过大 19.03，跳过此次更新
# 警告：梯度范数过大 19.29，跳过此次更新
# 警告：梯度范数过大 15.26，跳过此次更新
# 警告：梯度范数过大 17.50，跳过此次更新
# 警告：梯度范数过大 22.56，跳过此次更新
# 警告：梯度范数过大 16.44，跳过此次更新
# 警告：梯度范数过大 22.35，跳过此次更新
# 警告：梯度范数过大 13.16，跳过此次更新
# 警告：梯度范数过大 15.50，跳过此次更新
# 警告：梯度范数过大 18.71，跳过此次更新
# 警告：梯度范数过大 18.94，跳过此次更新
# 警告：梯度范数过大 17.12，跳过此次更新
# 警告：梯度范数过大 16.27，跳过此次更新
# 警告：梯度范数过大 16.52，跳过此次更新
# 警告：梯度范数过大 16.11，跳过此次更新
# 警告：梯度范数过大 19.22，跳过此次更新
# 警告：梯度范数过大 17.29，跳过此次更新
# 警告：梯度范数过大 20.94，跳过此次更新
# 警告：梯度范数过大 14.25，跳过此次更新
# 警告：梯度范数过大 16.48，跳过此次更新
# 警告：梯度范数过大 19.43，跳过此次更新
# 警告：梯度范数过大 19.20，跳过此次更新
# 警告：梯度范数过大 15.46，跳过此次更新
# 警告：梯度范数过大 18.71，跳过此次更新
# 警告：梯度范数过大 16.44，跳过此次更新
# 警告：梯度范数过大 22.35，跳过此次更新
# 警告：梯度范数过大 13.16，跳过此次更新
# 警告：梯度范数过大 15.50，跳过此次更新
# 警告：梯度范数过大 18.71，跳过此次更新
# 警告：梯度范数过大 18.94，跳过此次更新
# 警告：梯度范数过大 17.12，跳过此次更新
# 警告：梯度范数过大 16.27，跳过此次更新
# 警告：梯度范数过大 16.52，跳过此次更新
# 警告：梯度范数过大 16.11，跳过此次更新
# 警告：梯度范数过大 19.22，跳过此次更新
# 警告：梯度范数过大 17.29，跳过此次更新
# 警告：梯度范数过大 20.94，跳过此次更新
# 警告：梯度范数过大 14.25，跳过此次更新
# 警告：梯度范数过大 16.48，跳过此次更新
# 警告：梯度范数过大 19.43，跳过此次更新
# 警告：梯度范数过大 19.20，跳过此次更新
# 警告：梯度范数过大 15.46，跳过此次更新
# 警告：梯度范数过大 18.71，跳过此次更新
# 警告：梯度范数过大 17.30，跳过此次更新
# 警告：梯度范数过大 14.09，跳过此次更新
# 警告：梯度范数过大 18.52，跳过此次更新
# 警告：梯度范数过大 15.94，跳过此次更新
# 警告：梯度范数过大 16.08，跳过此次更新
# 警告：梯度范数过大 17.05，跳过此次更新
# 警告：梯度范数过大 17.61，跳过此次更新
# 警告：梯度范数过大 18.27，跳过此次更新
# 警告：梯度范数过大 16.91，跳过此次更新
# 警告：梯度范数过大 16.44，跳过此次更新
# 警告：梯度范数过大 20.42，跳过此次更新
# 警告：梯度范数过大 15.76，跳过此次更新
# 警告：梯度范数过大 19.48，跳过此次更新
# 警告：梯度范数过大 17.53，跳过此次更新
# 警告：梯度范数过大 12.44，跳过此次更新
# 警告：梯度范数过大 21.56，跳过此次更新
# 警告：梯度范数过大 16.53，跳过此次更新
# 警告：梯度范数过大 16.21，跳过此次更新
# 警告：梯度范数过大 17.62，跳过此次更新
# 警告：梯度范数过大 14.82，跳过此次更新
# 警告：梯度范数过大 17.30，跳过此次更新
# 警告：梯度范数过大 14.09，跳过此次更新
# 警告：梯度范数过大 18.52，跳过此次更新
# 警告：梯度范数过大 15.94，跳过此次更新
# 警告：梯度范数过大 16.08，跳过此次更新
# 警告：梯度范数过大 17.05，跳过此次更新
# 警告：梯度范数过大 17.61，跳过此次更新
# 警告：梯度范数过大 18.27，跳过此次更新
# 警告：梯度范数过大 16.91，跳过此次更新
# 警告：梯度范数过大 16.44，跳过此次更新
# 警告：梯度范数过大 20.42，跳过此次更新
# 警告：梯度范数过大 15.76，跳过此次更新
# 警告：梯度范数过大 19.48，跳过此次更新
# 警告：梯度范数过大 17.53，跳过此次更新
# 警告：梯度范数过大 12.44，跳过此次更新
# 警告：梯度范数过大 21.56，跳过此次更新
# 警告：梯度范数过大 16.53，跳过此次更新
# 警告：梯度范数过大 16.21，跳过此次更新
# 警告：梯度范数过大 17.62，跳过此次更新
# 警告：梯度范数过大 14.82，跳过此次更新
# 警告：梯度范数过大 21.59，跳过此次更新
# 警告：梯度范数过大 19.57，跳过此次更新
# 警告：梯度范数过大 15.68，跳过此次更新
# 警告：梯度范数过大 21.65，跳过此次更新
# 警告：梯度范数过大 18.69，跳过此次更新
# 警告：梯度范数过大 14.05，跳过此次更新
# 警告：梯度范数过大 17.62，跳过此次更新
# 警告：梯度范数过大 15.77，跳过此次更新
# 警告：梯度范数过大 17.37，跳过此次更新
# 警告：梯度范数过大 19.75，跳过此次更新
# 警告：梯度范数过大 16.66，跳过此次更新
# 警告：梯度范数过大 15.56，跳过此次更新
# 警告：梯度范数过大 13.47，跳过此次更新
# 警告：梯度范数过大 18.76，跳过此次更新
# 警告：梯度范数过大 12.76，跳过此次更新
# 警告：梯度范数过大 15.83，跳过此次更新
# 警告：梯度范数过大 17.85，跳过此次更新
# 警告：梯度范数过大 14.41，跳过此次更新
# 警告：梯度范数过大 12.75，跳过此次更新
# 警告：梯度范数过大 21.86，跳过此次更新
# 警告：梯度范数过大 20.21，跳过此次更新
# 警告：梯度范数过大 21.59，跳过此次更新
# 警告：梯度范数过大 19.57，跳过此次更新
# 警告：梯度范数过大 15.68，跳过此次更新
# 警告：梯度范数过大 21.65，跳过此次更新
# 警告：梯度范数过大 18.69，跳过此次更新
# 警告：梯度范数过大 14.05，跳过此次更新
# 警告：梯度范数过大 17.62，跳过此次更新
# 警告：梯度范数过大 15.77，跳过此次更新
# 警告：梯度范数过大 17.37，跳过此次更新
# 警告：梯度范数过大 19.75，跳过此次更新
# 警告：梯度范数过大 16.66，跳过此次更新
# 警告：梯度范数过大 15.56，跳过此次更新
# 警告：梯度范数过大 13.47，跳过此次更新
# 警告：梯度范数过大 18.76，跳过此次更新
# 警告：梯度范数过大 12.76，跳过此次更新
# 警告：梯度范数过大 15.83，跳过此次更新
# 警告：梯度范数过大 17.85，跳过此次更新
# 警告：梯度范数过大 14.41，跳过此次更新
# 警告：梯度范数过大 12.75，跳过此次更新
# 警告：梯度范数过大 21.86，跳过此次更新
# 警告：梯度范数过大 20.21，跳过此次更新
# 警告：梯度范数过大 18.67，跳过此次更新
# 警告：梯度范数过大 24.46，跳过此次更新
# 警告：梯度范数过大 11.77，跳过此次更新
# 警告：梯度范数过大 17.24，跳过此次更新
# 警告：梯度范数过大 10.71，跳过此次更新
# 警告：梯度范数过大 16.82，跳过此次更新
# 警告：梯度范数过大 15.33，跳过此次更新
# 警告：梯度范数过大 16.23，跳过此次更新
# 警告：梯度范数过大 19.14，跳过此次更新
# 警告：梯度范数过大 15.15，跳过此次更新
# 警告：梯度范数过大 15.22，跳过此次更新
# 警告：梯度范数过大 17.53，跳过此次更新
# 警告：梯度范数过大 17.15，跳过此次更新
# 警告：梯度范数过大 14.41，跳过此次更新
# 警告：梯度范数过大 15.62，跳过此次更新
# 警告：梯度范数过大 17.58，跳过此次更新
# 警告：梯度范数过大 17.49，跳过此次更新
# 警告：梯度范数过大 11.58，跳过此次更新
# 警告：梯度范数过大 15.41，跳过此次更新
# 警告：梯度范数过大 15.31，跳过此次更新
# 警告：梯度范数过大 18.67，跳过此次更新
# 警告：梯度范数过大 24.46，跳过此次更新
# 警告：梯度范数过大 11.77，跳过此次更新
# 警告：梯度范数过大 17.24，跳过此次更新
# 警告：梯度范数过大 10.71，跳过此次更新
# 警告：梯度范数过大 16.82，跳过此次更新
# 警告：梯度范数过大 15.33，跳过此次更新
# 警告：梯度范数过大 16.23，跳过此次更新
# 警告：梯度范数过大 19.14，跳过此次更新
# 警告：梯度范数过大 15.15，跳过此次更新
# 警告：梯度范数过大 15.22，跳过此次更新
# 警告：梯度范数过大 17.53，跳过此次更新
# 警告：梯度范数过大 17.15，跳过此次更新
# 警告：梯度范数过大 14.41，跳过此次更新
# 警告：梯度范数过大 15.62，跳过此次更新
# 警告：梯度范数过大 17.58，跳过此次更新
# 警告：梯度范数过大 17.49，跳过此次更新
# 警告：梯度范数过大 11.58，跳过此次更新
# 警告：梯度范数过大 15.41，跳过此次更新
# 警告：梯度范数过大 15.31，跳过此次更新
# 警告：梯度范数过大 21.55，跳过此次更新
# 警告：梯度范数过大 17.48，跳过此次更新
# 警告：梯度范数过大 19.89，跳过此次更新
# 警告：梯度范数过大 16.27，跳过此次更新
# 警告：梯度范数过大 16.38，跳过此次更新
# 警告：梯度范数过大 13.22，跳过此次更新
# 警告：梯度范数过大 15.51，跳过此次更新
# 警告：梯度范数过大 18.21，跳过此次更新
# 警告：梯度范数过大 18.17，跳过此次更新
# 警告：梯度范数过大 12.64，跳过此次更新
# 警告：梯度范数过大 10.35，跳过此次更新
# 警告：梯度范数过大 19.07，跳过此次更新
# 警告：梯度范数过大 16.63，跳过此次更新
# 警告：梯度范数过大 21.36，跳过此次更新
# 警告：梯度范数过大 15.74，跳过此次更新
# 警告：梯度范数过大 18.24，跳过此次更新
# 警告：梯度范数过大 13.98，跳过此次更新
# 警告：梯度范数过大 12.14，跳过此次更新
# 警告：梯度范数过大 19.16，跳过此次更新
# 警告：梯度范数过大 15.35，跳过此次更新
# 警告：梯度范数过大 21.55，跳过此次更新
# 警告：梯度范数过大 17.48，跳过此次更新
# 警告：梯度范数过大 19.89，跳过此次更新
# 警告：梯度范数过大 16.27，跳过此次更新
# 警告：梯度范数过大 16.38，跳过此次更新
# 警告：梯度范数过大 13.22，跳过此次更新
# 警告：梯度范数过大 15.51，跳过此次更新
# 警告：梯度范数过大 18.21，跳过此次更新
# 警告：梯度范数过大 18.17，跳过此次更新
# 警告：梯度范数过大 12.64，跳过此次更新
# 警告：梯度范数过大 10.35，跳过此次更新
# 警告：梯度范数过大 19.07，跳过此次更新
# 警告：梯度范数过大 16.63，跳过此次更新
# 警告：梯度范数过大 21.36，跳过此次更新
# 警告：梯度范数过大 15.74，跳过此次更新
# 警告：梯度范数过大 18.24，跳过此次更新
# 警告：梯度范数过大 13.98，跳过此次更新
# 警告：梯度范数过大 12.14，跳过此次更新
# 警告：梯度范数过大 19.16，跳过此次更新
# 警告：梯度范数过大 15.35，跳过此次更新
# 警告：梯度范数过大 14.25，跳过此次更新
# 警告：梯度范数过大 20.38，跳过此次更新
# 警告：梯度范数过大 16.35，跳过此次更新
# 警告：梯度范数过大 14.98，跳过此次更新
# 警告：梯度范数过大 15.35，跳过此次更新
# 警告：梯度范数过大 20.12，跳过此次更新
# 警告：梯度范数过大 18.35，跳过此次更新
# 警告：梯度范数过大 19.69，跳过此次更新
# 警告：梯度范数过大 18.63，跳过此次更新
# 警告：梯度范数过大 15.10，跳过此次更新
# 警告：梯度范数过大 12.65，跳过此次更新
# 警告：梯度范数过大 13.82，跳过此次更新
# 警告：梯度范数过大 20.22，跳过此次更新
# 警告：梯度范数过大 15.23，跳过此次更新
# 警告：梯度范数过大 12.64，跳过此次更新
# 警告：梯度范数过大 13.52，跳过此次更新
# 警告：梯度范数过大 17.60，跳过此次更新
# 警告：梯度范数过大 20.89，跳过此次更新
# 警告：梯度范数过大 15.55，跳过此次更新
# 警告：梯度范数过大 21.40，跳过此次更新
# 警告：梯度范数过大 14.25，跳过此次更新
# 警告：梯度范数过大 20.38，跳过此次更新
# 警告：梯度范数过大 16.35，跳过此次更新
# 警告：梯度范数过大 14.98，跳过此次更新
# 警告：梯度范数过大 15.35，跳过此次更新
# 警告：梯度范数过大 20.12，跳过此次更新
# 警告：梯度范数过大 18.35，跳过此次更新
# 警告：梯度范数过大 19.69，跳过此次更新
# 警告：梯度范数过大 18.63，跳过此次更新
# 警告：梯度范数过大 15.10，跳过此次更新
# 警告：梯度范数过大 12.65，跳过此次更新
# 警告：梯度范数过大 13.82，跳过此次更新
# 警告：梯度范数过大 20.22，跳过此次更新
# 警告：梯度范数过大 15.23，跳过此次更新
# 警告：梯度范数过大 12.64，跳过此次更新
# 警告：梯度范数过大 13.52，跳过此次更新
# 警告：梯度范数过大 17.60，跳过此次更新
# 警告：梯度范数过大 20.89，跳过此次更新
# 警告：梯度范数过大 15.55，跳过此次更新
# 警告：梯度范数过大 21.40，跳过此次更新
# 警告：梯度范数过大 18.49，跳过此次更新
# 警告：梯度范数过大 18.99，跳过此次更新
# 警告：梯度范数过大 18.49，跳过此次更新
# 警告：梯度范数过大 18.99，跳过此次更新
# Epoch 5/15: Train Loss: 1.062787, Val Loss: 1.595814, LR: 0.001000
# 警告：梯度范数过大 17.39，跳过此次更新
# 警告：梯度范数过大 14.14，跳过此次更新
# 警告：梯度范数过大 15.95，跳过此次更新
# 警告：梯度范数过大 16.23，跳过此次更新
# 警告：梯度范数过大 16.19，跳过此次更新
# 警告：梯度范数过大 14.72，跳过此次更新
# 警告：梯度范数过大 20.26，跳过此次更新
# 警告：梯度范数过大 18.20，跳过此次更新
# 警告：梯度范数过大 17.18，跳过此次更新
# 警告：梯度范数过大 14.59，跳过此次更新
# 警告：梯度范数过大 19.43，跳过此次更新
# 警告：梯度范数过大 22.66，跳过此次更新
# 警告：梯度范数过大 19.63，跳过此次更新
# 警告：梯度范数过大 16.31，跳过此次更新
# 警告：梯度范数过大 21.47，跳过此次更新
# 警告：梯度范数过大 21.49，跳过此次更新
# 警告：梯度范数过大 18.81，跳过此次更新
# 警告：梯度范数过大 17.13，跳过此次更新
# 警告：梯度范数过大 17.20，跳过此次更新
# 警告：梯度范数过大 12.78，跳过此次更新
# Epoch 5/15: Train Loss: 1.062787, Val Loss: 1.595814, LR: 0.001000
# 警告：梯度范数过大 17.39，跳过此次更新
# 警告：梯度范数过大 14.14，跳过此次更新
# 警告：梯度范数过大 15.95，跳过此次更新
# 警告：梯度范数过大 16.23，跳过此次更新
# 警告：梯度范数过大 16.19，跳过此次更新
# 警告：梯度范数过大 14.72，跳过此次更新
# 警告：梯度范数过大 20.26，跳过此次更新
# 警告：梯度范数过大 18.20，跳过此次更新
# 警告：梯度范数过大 17.18，跳过此次更新
# 警告：梯度范数过大 14.59，跳过此次更新
# 警告：梯度范数过大 19.43，跳过此次更新
# 警告：梯度范数过大 22.66，跳过此次更新
# 警告：梯度范数过大 19.63，跳过此次更新
# 警告：梯度范数过大 16.31，跳过此次更新
# 警告：梯度范数过大 21.47，跳过此次更新
# 警告：梯度范数过大 21.49，跳过此次更新
# 警告：梯度范数过大 18.81，跳过此次更新
# 警告：梯度范数过大 17.13，跳过此次更新
# 警告：梯度范数过大 17.20，跳过此次更新
# 警告：梯度范数过大 12.78，跳过此次更新
# 警告：梯度范数过大 18.33，跳过此次更新
# 警告：梯度范数过大 15.49，跳过此次更新
# 警告：梯度范数过大 13.61，跳过此次更新
# 警告：梯度范数过大 17.08，跳过此次更新
# 警告：梯度范数过大 17.71，跳过此次更新
# 警告：梯度范数过大 18.90，跳过此次更新
# 警告：梯度范数过大 17.92，跳过此次更新
# 警告：梯度范数过大 22.76，跳过此次更新
# 警告：梯度范数过大 20.09，跳过此次更新
# 警告：梯度范数过大 18.08，跳过此次更新
# 警告：梯度范数过大 22.12，跳过此次更新
# 警告：梯度范数过大 18.99，跳过此次更新
# 警告：梯度范数过大 14.88，跳过此次更新
# 警告：梯度范数过大 17.92，跳过此次更新
# 警告：梯度范数过大 14.29，跳过此次更新
# 警告：梯度范数过大 16.53，跳过此次更新
# 警告：梯度范数过大 17.97，跳过此次更新
# 警告：梯度范数过大 15.84，跳过此次更新
# 警告：梯度范数过大 18.07，跳过此次更新
# 警告：梯度范数过大 19.81，跳过此次更新
# 警告：梯度范数过大 18.33，跳过此次更新
# 警告：梯度范数过大 15.49，跳过此次更新
# 警告：梯度范数过大 13.61，跳过此次更新
# 警告：梯度范数过大 17.08，跳过此次更新
# 警告：梯度范数过大 17.71，跳过此次更新
# 警告：梯度范数过大 18.90，跳过此次更新
# 警告：梯度范数过大 17.92，跳过此次更新
# 警告：梯度范数过大 22.76，跳过此次更新
# 警告：梯度范数过大 20.09，跳过此次更新
# 警告：梯度范数过大 18.08，跳过此次更新
# 警告：梯度范数过大 22.12，跳过此次更新
# 警告：梯度范数过大 18.99，跳过此次更新
# 警告：梯度范数过大 14.88，跳过此次更新
# 警告：梯度范数过大 17.92，跳过此次更新
# 警告：梯度范数过大 14.29，跳过此次更新
# 警告：梯度范数过大 16.53，跳过此次更新
# 警告：梯度范数过大 17.97，跳过此次更新
# 警告：梯度范数过大 15.84，跳过此次更新
# 警告：梯度范数过大 18.07，跳过此次更新
# 警告：梯度范数过大 19.81，跳过此次更新
# 警告：梯度范数过大 18.10，跳过此次更新
# 警告：梯度范数过大 15.25，跳过此次更新
# 警告：梯度范数过大 17.17，跳过此次更新
# 警告：梯度范数过大 17.88，跳过此次更新
# 警告：梯度范数过大 13.68，跳过此次更新
# 警告：梯度范数过大 15.31，跳过此次更新
# 警告：梯度范数过大 14.15，跳过此次更新
# 警告：梯度范数过大 19.18，跳过此次更新
# 警告：梯度范数过大 19.09，跳过此次更新
# 警告：梯度范数过大 16.83，跳过此次更新
# 警告：梯度范数过大 15.21，跳过此次更新
# 警告：梯度范数过大 18.13，跳过此次更新
# 警告：梯度范数过大 18.86，跳过此次更新
# 警告：梯度范数过大 17.87，跳过此次更新
# 警告：梯度范数过大 19.96，跳过此次更新
# 警告：梯度范数过大 19.71，跳过此次更新
# 警告：梯度范数过大 16.54，跳过此次更新
# 警告：梯度范数过大 18.15，跳过此次更新
# 警告：梯度范数过大 13.47，跳过此次更新
# 警告：梯度范数过大 13.62，跳过此次更新
# 警告：梯度范数过大 18.10，跳过此次更新
# 警告：梯度范数过大 15.25，跳过此次更新
# 警告：梯度范数过大 17.17，跳过此次更新
# 警告：梯度范数过大 17.88，跳过此次更新
# 警告：梯度范数过大 13.68，跳过此次更新
# 警告：梯度范数过大 15.31，跳过此次更新
# 警告：梯度范数过大 14.15，跳过此次更新
# 警告：梯度范数过大 19.18，跳过此次更新
# 警告：梯度范数过大 19.09，跳过此次更新
# 警告：梯度范数过大 16.83，跳过此次更新
# 警告：梯度范数过大 15.21，跳过此次更新
# 警告：梯度范数过大 18.13，跳过此次更新
# 警告：梯度范数过大 18.86，跳过此次更新
# 警告：梯度范数过大 17.87，跳过此次更新
# 警告：梯度范数过大 19.96，跳过此次更新
# 警告：梯度范数过大 19.71，跳过此次更新
# 警告：梯度范数过大 16.54，跳过此次更新
# 警告：梯度范数过大 18.15，跳过此次更新
# 警告：梯度范数过大 13.47，跳过此次更新
# 警告：梯度范数过大 13.62，跳过此次更新
# 警告：梯度范数过大 12.99，跳过此次更新
# 警告：梯度范数过大 11.91，跳过此次更新
# 警告：梯度范数过大 19.70，跳过此次更新
# 警告：梯度范数过大 13.70，跳过此次更新
# 警告：梯度范数过大 13.47，跳过此次更新
# 警告：梯度范数过大 13.31，跳过此次更新
# 警告：梯度范数过大 11.85，跳过此次更新
# 警告：梯度范数过大 12.41，跳过此次更新
# 警告：梯度范数过大 11.88，跳过此次更新
# 警告：梯度范数过大 11.52，跳过此次更新
# 警告：梯度范数过大 12.33，跳过此次更新
# 警告：梯度范数过大 11.22，跳过此次更新
# 警告：梯度范数过大 13.10，跳过此次更新
# 警告：梯度范数过大 12.65，跳过此次更新
# 警告：梯度范数过大 10.04，跳过此次更新
# 警告：梯度范数过大 12.99，跳过此次更新
# 警告：梯度范数过大 11.91，跳过此次更新
# 警告：梯度范数过大 19.70，跳过此次更新
# 警告：梯度范数过大 13.70，跳过此次更新
# 警告：梯度范数过大 13.47，跳过此次更新
# 警告：梯度范数过大 13.31，跳过此次更新
# 警告：梯度范数过大 11.85，跳过此次更新
# 警告：梯度范数过大 12.41，跳过此次更新
# 警告：梯度范数过大 11.88，跳过此次更新
# 警告：梯度范数过大 11.52，跳过此次更新
# 警告：梯度范数过大 12.33，跳过此次更新
# 警告：梯度范数过大 11.22，跳过此次更新
# 警告：梯度范数过大 13.10，跳过此次更新
# 警告：梯度范数过大 12.65，跳过此次更新
# 警告：梯度范数过大 10.04，跳过此次更新
# 警告：梯度范数过大 12.58，跳过此次更新
# 警告：梯度范数过大 16.83，跳过此次更新
# 警告：梯度范数过大 21.66，跳过此次更新
# 警告：梯度范数过大 11.29，跳过此次更新
# 警告：梯度范数过大 12.25，跳过此次更新
# 警告：梯度范数过大 12.58，跳过此次更新
# 警告：梯度范数过大 16.83，跳过此次更新
# 警告：梯度范数过大 21.66，跳过此次更新
# 警告：梯度范数过大 11.29，跳过此次更新
# 警告：梯度范数过大 12.25，跳过此次更新
# 警告：梯度范数过大 12.06，跳过此次更新
# 警告：梯度范数过大 12.06，跳过此次更新
# 警告：梯度范数过大 10.13，跳过此次更新
# 警告：梯度范数过大 10.13，跳过此次更新
# 警告：梯度范数过大 14.53，跳过此次更新
# 警告：梯度范数过大 14.53，跳过此次更新
# 警告：梯度范数过大 34.07，跳过此次更新
# 警告：梯度范数过大 34.07，跳过此次更新
# 警告：梯度范数过大 10.64，跳过此次更新
# 警告：梯度范数过大 10.64，跳过此次更新
# Epoch 6/15: Train Loss: 0.313520, Val Loss: 0.239479, LR: 0.001000
# 保存最佳模型，验证损失: 0.239479
# Epoch 6/15: Train Loss: 0.313520, Val Loss: 0.239479, LR: 0.001000
# 保存最佳模型，验证损失: 0.239479
# 警告：梯度范数过大 16.33，跳过此次更新
# 警告：梯度范数过大 16.33，跳过此次更新
# Epoch 7/15: Train Loss: 0.274893, Val Loss: 0.236274, LR: 0.001000
# 保存最佳模型，验证损失: 0.236274
# Epoch 7/15: Train Loss: 0.274893, Val Loss: 0.236274, LR: 0.001000
# 保存最佳模型，验证损失: 0.236274
# Epoch 8/15: Train Loss: 0.270857, Val Loss: 0.255020, LR: 0.001000
# Epoch 8/15: Train Loss: 0.270857, Val Loss: 0.255020, LR: 0.001000
# Epoch 9/15: Train Loss: 0.266860, Val Loss: 0.226884, LR: 0.001000
# 保存最佳模型，验证损失: 0.226884
# Epoch 9/15: Train Loss: 0.266860, Val Loss: 0.226884, LR: 0.001000
# 保存最佳模型，验证损失: 0.226884
# Epoch 10/15: Train Loss: 0.266171, Val Loss: 0.239513, LR: 0.001000
# Epoch 10/15: Train Loss: 0.266171, Val Loss: 0.239513, LR: 0.001000
# Epoch 11/15: Train Loss: 0.263908, Val Loss: 0.228799, LR: 0.001000
# Epoch 11/15: Train Loss: 0.263908, Val Loss: 0.228799, LR: 0.001000
# Epoch 12/15: Train Loss: 0.261613, Val Loss: 0.234291, LR: 0.001000
# Epoch 12/15: Train Loss: 0.261613, Val Loss: 0.234291, LR: 0.001000
# Epoch 13/15: Train Loss: 0.260294, Val Loss: 0.228541, LR: 0.001000
# Epoch 13/15: Train Loss: 0.260294, Val Loss: 0.228541, LR: 0.001000
# Epoch 14/15: Train Loss: 0.259032, Val Loss: 0.226913, LR: 0.001000
# Early stopping at epoch 14
# 成功加载最佳模型
# Epoch 14/15: Train Loss: 0.259032, Val Loss: 0.226913, LR: 0.001000
# Early stopping at epoch 14
# 成功加载最佳模型
# 验证损失: 0.226884
# 发现更好的参数组合! 损失: 0.226884
#
# 调优进度: 2/4
# 当前参数: {'d_model': 256, 'nhead': 8, 'num_layers': 6, 'learning_rate': 0.001, 'dropout': 0.1}
# 注意：使用兼容模式的学习率调度器
# 开始训练，初始学习率: 0.001000
# 验证损失: 0.226884
# 发现更好的参数组合! 损失: 0.226884
#
# 调优进度: 2/4
# 当前参数: {'d_model': 256, 'nhead': 8, 'num_layers': 6, 'learning_rate': 0.001, 'dropout': 0.1}
# 注意：使用兼容模式的学习率调度器
# 开始训练，初始学习率: 0.001000
# Epoch 1/15: Train Loss: 1.078347, Val Loss: 0.699143, LR: 0.001000
# 保存最佳模型，验证损失: 0.699143
# Epoch 1/15: Train Loss: 1.078347, Val Loss: 0.699143, LR: 0.001000
# 保存最佳模型，验证损失: 0.699143
# Epoch 2/15: Train Loss: 1.078392, Val Loss: 0.697122, LR: 0.001000
# 保存最佳模型，验证损失: 0.697122
# Epoch 2/15: Train Loss: 1.078392, Val Loss: 0.697122, LR: 0.001000
# 保存最佳模型，验证损失: 0.697122
# Epoch 3/15: Train Loss: 1.078329, Val Loss: 0.696127, LR: 0.001000
# 保存最佳模型，验证损失: 0.696127
# Epoch 3/15: Train Loss: 1.078329, Val Loss: 0.696127, LR: 0.001000
# 保存最佳模型，验证损失: 0.696127
# Epoch 4/15: Train Loss: 1.078393, Val Loss: 0.696068, LR: 0.001000
# 保存最佳模型，验证损失: 0.696068
# Epoch 4/15: Train Loss: 1.078393, Val Loss: 0.696068, LR: 0.001000
# 保存最佳模型，验证损失: 0.696068
# Epoch 5/15: Train Loss: 1.078344, Val Loss: 0.697806, LR: 0.001000
# Epoch 5/15: Train Loss: 1.078344, Val Loss: 0.697806, LR: 0.001000
# Epoch 6/15: Train Loss: 1.078307, Val Loss: 0.699014, LR: 0.001000
# Epoch 6/15: Train Loss: 1.078307, Val Loss: 0.699014, LR: 0.001000
# Epoch 7/15: Train Loss: 1.078343, Val Loss: 0.697340, LR: 0.001000
# Epoch 7/15: Train Loss: 1.078343, Val Loss: 0.697340, LR: 0.001000
# Epoch 8/15: Train Loss: 1.078299, Val Loss: 0.697485, LR: 0.001000
# Epoch 8/15: Train Loss: 1.078299, Val Loss: 0.697485, LR: 0.001000
# 学习率从 0.001000 降低到 0.000700
# Epoch 9/15: Train Loss: 1.078362, Val Loss: 0.696931, LR: 0.000700
# Early stopping at epoch 9
# 成功加载最佳模型
# 学习率从 0.001000 降低到 0.000700
# Epoch 9/15: Train Loss: 1.078362, Val Loss: 0.696931, LR: 0.000700
# Early stopping at epoch 9
# 成功加载最佳模型
# 验证损失: 0.696068
#
# 调优进度: 3/4
# 当前参数: {'d_model': 256, 'nhead': 8, 'num_layers': 4, 'learning_rate': 0.01, 'dropout': 0.2}
# 注意：使用兼容模式的学习率调度器
# 开始训练，初始学习率: 0.010000
# 验证损失: 0.696068
#
# 调优进度: 3/4
# 当前参数: {'d_model': 256, 'nhead': 8, 'num_layers': 4, 'learning_rate': 0.01, 'dropout': 0.2}
# 注意：使用兼容模式的学习率调度器
# 开始训练，初始学习率: 0.010000
# Epoch 1/15: Train Loss: 1.083004, Val Loss: 0.695705, LR: 0.010000
# 保存最佳模型，验证损失: 0.695705
# Epoch 1/15: Train Loss: 1.083004, Val Loss: 0.695705, LR: 0.010000
# 保存最佳模型，验证损失: 0.695705
# Epoch 2/15: Train Loss: 1.079322, Val Loss: 0.698607, LR: 0.010000
# Epoch 2/15: Train Loss: 1.079322, Val Loss: 0.698607, LR: 0.010000
# 警告：梯度范数过大 12.91，跳过此次更新
# 警告：梯度范数过大 12.91，跳过此次更新
# 警告：梯度范数过大 12.62，跳过此次更新
# 警告：梯度范数过大 10.62，跳过此次更新
# 警告：梯度范数过大 12.62，跳过此次更新
# 警告：梯度范数过大 10.62，跳过此次更新
# 警告：梯度范数过大 19.80，跳过此次更新
# 警告：梯度范数过大 13.91，跳过此次更新
# 警告：梯度范数过大 34.29，跳过此次更新
# 警告：梯度范数过大 26.07，跳过此次更新
# 警告：梯度范数过大 27.00，跳过此次更新
# 警告：梯度范数过大 32.34，跳过此次更新
# 警告：梯度范数过大 21.45，跳过此次更新
# 警告：梯度范数过大 23.48，跳过此次更新
# 警告：梯度范数过大 18.73，跳过此次更新
# 警告：梯度范数过大 19.80，跳过此次更新
# 警告：梯度范数过大 13.91，跳过此次更新
# 警告：梯度范数过大 34.29，跳过此次更新
# 警告：梯度范数过大 26.07，跳过此次更新
# 警告：梯度范数过大 27.00，跳过此次更新
# 警告：梯度范数过大 32.34，跳过此次更新
# 警告：梯度范数过大 21.45，跳过此次更新
# 警告：梯度范数过大 23.48，跳过此次更新
# 警告：梯度范数过大 18.73，跳过此次更新
# 警告：梯度范数过大 19.52，跳过此次更新
# 警告：梯度范数过大 28.67，跳过此次更新
# 警告：梯度范数过大 25.84，跳过此次更新
# 警告：梯度范数过大 37.68，跳过此次更新
# 警告：梯度范数过大 39.06，跳过此次更新
# 警告：梯度范数过大 16.76，跳过此次更新
# 警告：梯度范数过大 14.79，跳过此次更新
# 警告：梯度范数过大 24.65，跳过此次更新
# 警告：梯度范数过大 24.52，跳过此次更新
# 警告：梯度范数过大 39.37，跳过此次更新
# 警告：梯度范数过大 19.08，跳过此次更新
# 警告：梯度范数过大 19.52，跳过此次更新
# 警告：梯度范数过大 28.67，跳过此次更新
# 警告：梯度范数过大 25.84，跳过此次更新
# 警告：梯度范数过大 37.68，跳过此次更新
# 警告：梯度范数过大 39.06，跳过此次更新
# 警告：梯度范数过大 16.76，跳过此次更新
# 警告：梯度范数过大 14.79，跳过此次更新
# 警告：梯度范数过大 24.65，跳过此次更新
# 警告：梯度范数过大 24.52，跳过此次更新
# 警告：梯度范数过大 39.37，跳过此次更新
# 警告：梯度范数过大 19.08，跳过此次更新
# 警告：梯度范数过大 35.63，跳过此次更新
# 警告：梯度范数过大 39.88，跳过此次更新
# 警告：梯度范数过大 30.70，跳过此次更新
# 警告：梯度范数过大 19.08，跳过此次更新
# 警告：梯度范数过大 36.49，跳过此次更新
# 警告：梯度范数过大 28.18，跳过此次更新
# 警告：梯度范数过大 24.63，跳过此次更新
# 警告：梯度范数过大 36.82，跳过此次更新
# 警告：梯度范数过大 33.76，跳过此次更新
# 警告：梯度范数过大 39.52，跳过此次更新
# 警告：梯度范数过大 28.74，跳过此次更新
# 警告：梯度范数过大 35.63，跳过此次更新
# 警告：梯度范数过大 39.88，跳过此次更新
# 警告：梯度范数过大 30.70，跳过此次更新
# 警告：梯度范数过大 19.08，跳过此次更新
# 警告：梯度范数过大 36.49，跳过此次更新
# 警告：梯度范数过大 28.18，跳过此次更新
# 警告：梯度范数过大 24.63，跳过此次更新
# 警告：梯度范数过大 36.82，跳过此次更新
# 警告：梯度范数过大 33.76，跳过此次更新
# 警告：梯度范数过大 39.52，跳过此次更新
# 警告：梯度范数过大 28.74，跳过此次更新
# 警告：梯度范数过大 28.19，跳过此次更新
# 警告：梯度范数过大 28.67，跳过此次更新
# 警告：梯度范数过大 30.09，跳过此次更新
# 警告：梯度范数过大 29.65，跳过此次更新
# 警告：梯度范数过大 21.42，跳过此次更新
# 警告：梯度范数过大 16.33，跳过此次更新
# 警告：梯度范数过大 21.20，跳过此次更新
# 警告：梯度范数过大 50.02，跳过此次更新
# 警告：梯度范数过大 29.36，跳过此次更新
# 警告：梯度范数过大 17.84，跳过此次更新
# 警告：梯度范数过大 22.20，跳过此次更新
# 警告：梯度范数过大 28.19，跳过此次更新
# 警告：梯度范数过大 28.67，跳过此次更新
# 警告：梯度范数过大 30.09，跳过此次更新
# 警告：梯度范数过大 29.65，跳过此次更新
# 警告：梯度范数过大 21.42，跳过此次更新
# 警告：梯度范数过大 16.33，跳过此次更新
# 警告：梯度范数过大 21.20，跳过此次更新
# 警告：梯度范数过大 50.02，跳过此次更新
# 警告：梯度范数过大 29.36，跳过此次更新
# 警告：梯度范数过大 17.84，跳过此次更新
# 警告：梯度范数过大 22.20，跳过此次更新
# 警告：梯度范数过大 19.02，跳过此次更新
# 警告：梯度范数过大 30.65，跳过此次更新
# 警告：梯度范数过大 17.05，跳过此次更新
# 警告：梯度范数过大 20.26，跳过此次更新
# 警告：梯度范数过大 33.03，跳过此次更新
# 警告：梯度范数过大 22.12，跳过此次更新
# 警告：梯度范数过大 29.51，跳过此次更新
# 警告：梯度范数过大 19.70，跳过此次更新
# 警告：梯度范数过大 30.49，跳过此次更新
# 警告：梯度范数过大 15.02，跳过此次更新
# 警告：梯度范数过大 21.79，跳过此次更新
# 警告：梯度范数过大 19.02，跳过此次更新
# 警告：梯度范数过大 30.65，跳过此次更新
# 警告：梯度范数过大 17.05，跳过此次更新
# 警告：梯度范数过大 20.26，跳过此次更新
# 警告：梯度范数过大 33.03，跳过此次更新
# 警告：梯度范数过大 22.12，跳过此次更新
# 警告：梯度范数过大 29.51，跳过此次更新
# 警告：梯度范数过大 19.70，跳过此次更新
# 警告：梯度范数过大 30.49，跳过此次更新
# 警告：梯度范数过大 15.02，跳过此次更新
# 警告：梯度范数过大 21.79，跳过此次更新
# 警告：梯度范数过大 19.45，跳过此次更新
# 警告：梯度范数过大 26.21，跳过此次更新
# 警告：梯度范数过大 17.54，跳过此次更新
# 警告：梯度范数过大 26.78，跳过此次更新
# 警告：梯度范数过大 25.85，跳过此次更新
# 警告：梯度范数过大 29.54，跳过此次更新
# 警告：梯度范数过大 34.37，跳过此次更新
# 警告：梯度范数过大 17.67，跳过此次更新
# 警告：梯度范数过大 28.56，跳过此次更新
# 警告：梯度范数过大 17.60，跳过此次更新
# 警告：梯度范数过大 27.86，跳过此次更新
# 警告：梯度范数过大 19.45，跳过此次更新
# 警告：梯度范数过大 26.21，跳过此次更新
# 警告：梯度范数过大 17.54，跳过此次更新
# 警告：梯度范数过大 26.78，跳过此次更新
# 警告：梯度范数过大 25.85，跳过此次更新
# 警告：梯度范数过大 29.54，跳过此次更新
# 警告：梯度范数过大 34.37，跳过此次更新
# 警告：梯度范数过大 17.67，跳过此次更新
# 警告：梯度范数过大 28.56，跳过此次更新
# 警告：梯度范数过大 17.60，跳过此次更新
# 警告：梯度范数过大 27.86，跳过此次更新
# 警告：梯度范数过大 19.38，跳过此次更新
# 警告：梯度范数过大 27.92，跳过此次更新
# 警告：梯度范数过大 25.27，跳过此次更新
# 警告：梯度范数过大 15.51，跳过此次更新
# 警告：梯度范数过大 37.55，跳过此次更新
# 警告：梯度范数过大 23.50，跳过此次更新
# 警告：梯度范数过大 53.17，跳过此次更新
# 警告：梯度范数过大 25.27，跳过此次更新
# 警告：梯度范数过大 30.88，跳过此次更新
# 警告：梯度范数过大 33.60，跳过此次更新
# 警告：梯度范数过大 25.37，跳过此次更新
# 警告：梯度范数过大 19.38，跳过此次更新
# 警告：梯度范数过大 27.92，跳过此次更新
# 警告：梯度范数过大 25.27，跳过此次更新
# 警告：梯度范数过大 15.51，跳过此次更新
# 警告：梯度范数过大 37.55，跳过此次更新
# 警告：梯度范数过大 23.50，跳过此次更新
# 警告：梯度范数过大 53.17，跳过此次更新
# 警告：梯度范数过大 25.27，跳过此次更新
# 警告：梯度范数过大 30.88，跳过此次更新
# 警告：梯度范数过大 33.60，跳过此次更新
# 警告：梯度范数过大 25.37，跳过此次更新
# 警告：梯度范数过大 29.57，跳过此次更新
# 警告：梯度范数过大 48.51，跳过此次更新
# 警告：梯度范数过大 30.22，跳过此次更新
# 警告：梯度范数过大 31.58，跳过此次更新
# 警告：梯度范数过大 15.39，跳过此次更新
# 警告：梯度范数过大 26.32，跳过此次更新
# 警告：梯度范数过大 23.81，跳过此次更新
# 警告：梯度范数过大 34.57，跳过此次更新
# 警告：梯度范数过大 28.77，跳过此次更新
# 警告：梯度范数过大 20.29，跳过此次更新
# 警告：梯度范数过大 36.14，跳过此次更新
# 警告：梯度范数过大 29.57，跳过此次更新
# 警告：梯度范数过大 48.51，跳过此次更新
# 警告：梯度范数过大 30.22，跳过此次更新
# 警告：梯度范数过大 31.58，跳过此次更新
# 警告：梯度范数过大 15.39，跳过此次更新
# 警告：梯度范数过大 26.32，跳过此次更新
# 警告：梯度范数过大 23.81，跳过此次更新
# 警告：梯度范数过大 34.57，跳过此次更新
# 警告：梯度范数过大 28.77，跳过此次更新
# 警告：梯度范数过大 20.29，跳过此次更新
# 警告：梯度范数过大 36.14，跳过此次更新
# 警告：梯度范数过大 23.39，跳过此次更新
# 警告：梯度范数过大 28.68，跳过此次更新
# 警告：梯度范数过大 16.42，跳过此次更新
# 警告：梯度范数过大 22.98，跳过此次更新
# 警告：梯度范数过大 27.33，跳过此次更新
# 警告：梯度范数过大 30.41，跳过此次更新
# 警告：梯度范数过大 12.47，跳过此次更新
# 警告：梯度范数过大 26.02，跳过此次更新
# 警告：梯度范数过大 25.07，跳过此次更新
# 警告：梯度范数过大 27.45，跳过此次更新
# 警告：梯度范数过大 26.21，跳过此次更新
# 警告：梯度范数过大 23.39，跳过此次更新
# 警告：梯度范数过大 28.68，跳过此次更新
# 警告：梯度范数过大 16.42，跳过此次更新
# 警告：梯度范数过大 22.98，跳过此次更新
# 警告：梯度范数过大 27.33，跳过此次更新
# 警告：梯度范数过大 30.41，跳过此次更新
# 警告：梯度范数过大 12.47，跳过此次更新
# 警告：梯度范数过大 26.02，跳过此次更新
# 警告：梯度范数过大 25.07，跳过此次更新
# 警告：梯度范数过大 27.45，跳过此次更新
# 警告：梯度范数过大 26.21，跳过此次更新
# 警告：梯度范数过大 21.85，跳过此次更新
# 警告：梯度范数过大 27.40，跳过此次更新
# 警告：梯度范数过大 24.74，跳过此次更新
# 警告：梯度范数过大 26.29，跳过此次更新
# 警告：梯度范数过大 26.07，跳过此次更新
# 警告：梯度范数过大 17.61，跳过此次更新
# 警告：梯度范数过大 16.83，跳过此次更新
# 警告：梯度范数过大 23.40，跳过此次更新
# 警告：梯度范数过大 24.08，跳过此次更新
# 警告：梯度范数过大 30.83，跳过此次更新
# 警告：梯度范数过大 13.20，跳过此次更新
# 警告：梯度范数过大 21.85，跳过此次更新
# 警告：梯度范数过大 27.40，跳过此次更新
# 警告：梯度范数过大 24.74，跳过此次更新
# 警告：梯度范数过大 26.29，跳过此次更新
# 警告：梯度范数过大 26.07，跳过此次更新
# 警告：梯度范数过大 17.61，跳过此次更新
# 警告：梯度范数过大 16.83，跳过此次更新
# 警告：梯度范数过大 23.40，跳过此次更新
# 警告：梯度范数过大 24.08，跳过此次更新
# 警告：梯度范数过大 30.83，跳过此次更新
# 警告：梯度范数过大 13.20，跳过此次更新
# 警告：梯度范数过大 19.63，跳过此次更新
# 警告：梯度范数过大 18.69，跳过此次更新
# 警告：梯度范数过大 23.10，跳过此次更新
# 警告：梯度范数过大 39.37，跳过此次更新
# 警告：梯度范数过大 21.24，跳过此次更新
# 警告：梯度范数过大 18.78，跳过此次更新
# 警告：梯度范数过大 23.60，跳过此次更新
# ...
# 警告：梯度范数过大 103.77，跳过此次更新
# 警告：梯度范数过大 38.62，跳过此次更新
# 警告：梯度范数过大 87.53，跳过此次更新
# 警告：梯度范数过大 66.32，跳过此次更新
# 警告：梯度范数过大 91.76，跳过此次更新
# 警告：梯度范数过大 53.78，跳过此次更新
# 警告：梯度范数过大 63.08，跳过此次更新
# 警告：梯度范数过大 44.90，跳过此次更新
# 警告：梯度范数过大 48.15，跳过此次更新
# 警告：梯度范数过大 50.26，跳过此次更新
# 警告：梯度范数过大 63.12，跳过此次更新
# 警告：梯度范数过大 85.26，跳过此次更新
# 警告：梯度范数过大 85.96，跳过此次更新
# 警告：梯度范数过大 93.14，跳过此次更新
# 警告：梯度范数过大 28.22，跳过此次更新
# 警告：梯度范数过大 35.56，跳过此次更新
# 警告：梯度范数过大 85.71，跳过此次更新
# 警告：梯度范数过大 61.20，跳过此次更新
# 警告：梯度范数过大 53.82，跳过此次更新
# 警告：梯度范数过大 76.72，跳过此次更新
# 警告：梯度范数过大 52.75，跳过此次更新
# 警告：梯度范数过大 54.22，跳过此次更新
# 警告：梯度范数过大 66.58，跳过此次更新
# 警告：梯度范数过大 49.12，跳过此次更新
# 警告：梯度范数过大 60.01，跳过此次更新
# 警告：梯度范数过大 71.04，跳过此次更新
# 警告：梯度范数过大 60.26，跳过此次更新
# 警告：梯度范数过大 76.73，跳过此次更新
# 警告：梯度范数过大 52.17，跳过此次更新
# 警告：梯度范数过大 77.36，跳过此次更新
# 警告：梯度范数过大 79.30，跳过此次更新
# 警告：梯度范数过大 42.28，跳过此次更新
# 警告：梯度范数过大 69.32，跳过此次更新
# 警告：梯度范数过大 53.81，跳过此次更新
# 警告：梯度范数过大 33.23，跳过此次更新
# 警告：梯度范数过大 56.88，跳过此次更新
# 警告：梯度范数过大 47.23，跳过此次更新
# 警告：梯度范数过大 66.70，跳过此次更新
# 警告：梯度范数过大 31.73，跳过此次更新
# 警告：梯度范数过大 35.55，跳过此次更新
# 警告：梯度范数过大 69.30，跳过此次更新
# 警告：梯度范数过大 93.14，跳过此次更新
# 警告：梯度范数过大 46.31，跳过此次更新
# 警告：梯度范数过大 52.12，跳过此次更新
# 警告：梯度范数过大 40.74，跳过此次更新
# 警告：梯度范数过大 63.42，跳过此次更新
# 警告：梯度范数过大 39.47，跳过此次更新
# 警告：梯度范数过大 44.95，跳过此次更新
# 警告：梯度范数过大 86.72，跳过此次更新
# 警告：梯度范数过大 44.63，跳过此次更新
# 警告：梯度范数过大 74.89，跳过此次更新
# 警告：梯度范数过大 72.98，跳过此次更新
# 警告：梯度范数过大 59.61，跳过此次更新
# 警告：梯度范数过大 56.46，跳过此次更新
# 警告：梯度范数过大 63.72，跳过此次更新
# 警告：梯度范数过大 61.58，跳过此次更新
# 警告：梯度范数过大 63.54，跳过此次更新
# 警告：梯度范数过大 64.73，跳过此次更新
# 警告：梯度范数过大 113.29，跳过此次更新
# 警告：梯度范数过大 54.25，跳过此次更新
# 警告：梯度范数过大 44.90，跳过此次更新
# 警告：梯度范数过大 39.99，跳过此次更新
# 警告：梯度范数过大 74.50，跳过此次更新
# 警告：梯度范数过大 53.20，跳过此次更新
# 警告：梯度范数过大 57.16，跳过此次更新
# 警告：梯度范数过大 106.66，跳过此次更新
# 警告：梯度范数过大 93.94，跳过此次更新
# 警告：梯度范数过大 94.64，跳过此次更新
# 警告：梯度范数过大 54.23，跳过此次更新
# 警告：梯度范数过大 73.37，跳过此次更新
# 警告：梯度范数过大 52.84，跳过此次更新
# 警告：梯度范数过大 120.02，跳过此次更新
# 警告：梯度范数过大 86.04，跳过此次更新
# 警告：梯度范数过大 45.77，跳过此次更新
# 警告：梯度范数过大 61.89，跳过此次更新
# 警告：梯度范数过大 92.53，跳过此次更新
# 警告：梯度范数过大 84.19，跳过此次更新
# 警告：梯度范数过大 57.38，跳过此次更新
# 警告：梯度范数过大 71.17，跳过此次更新
# 警告：梯度范数过大 119.48，跳过此次更新
# 警告：梯度范数过大 73.14，跳过此次更新
# 警告：梯度范数过大 50.58，跳过此次更新
# 警告：梯度范数过大 80.55，跳过此次更新
# 警告：梯度范数过大 44.76，跳过此次更新
# 警告：梯度范数过大 54.21，跳过此次更新
# 警告：梯度范数过大 53.56，跳过此次更新
# 警告：梯度范数过大 104.66，跳过此次更新
# 警告：梯度范数过大 24.11，跳过此次更新
# 警告：梯度范数过大 111.95，跳过此次更新
# 警告：梯度范数过大 56.13，跳过此次更新
# 警告：梯度范数过大 39.17，跳过此次更新
# 警告：梯度范数过大 105.11，跳过此次更新
# 警告：梯度范数过大 36.09，跳过此次更新
# 警告：梯度范数过大 105.97，跳过此次更新
# 警告：梯度范数过大 65.76，跳过此次更新
# 警告：梯度范数过大 60.15，跳过此次更新
# 警告：梯度范数过大 96.48，跳过此次更新
# 警告：梯度范数过大 74.49，跳过此次更新
# 警告：梯度范数过大 66.35，跳过此次更新
# 警告：梯度范数过大 68.69，跳过此次更新
# 警告：梯度范数过大 63.34，跳过此次更新
# 警告：梯度范数过大 42.24，跳过此次更新
# 警告：梯度范数过大 83.21，跳过此次更新
# 警告：梯度范数过大 81.42，跳过此次更新
# 警告：梯度范数过大 58.17，跳过此次更新
# 警告：梯度范数过大 35.82，跳过此次更新
# 警告：梯度范数过大 56.25，跳过此次更新
# 警告：梯度范数过大 95.36，跳过此次更新
# 警告：梯度范数过大 63.57，跳过此次更新
# 警告：梯度范数过大 56.35，跳过此次更新
# 警告：梯度范数过大 114.46，跳过此次更新
# 警告：梯度范数过大 92.69，跳过此次更新
# 警告：梯度范数过大 39.63，跳过此次更新
# 警告：梯度范数过大 47.03，跳过此次更新
# 警告：梯度范数过大 62.96，跳过此次更新
# 警告：梯度范数过大 78.52，跳过此次更新
# 警告：梯度范数过大 47.71，跳过此次更新
# 警告：梯度范数过大 51.49，跳过此次更新
# 警告：梯度范数过大 90.04，跳过此次更新
# 警告：梯度范数过大 86.23，跳过此次更新
# 警告：梯度范数过大 46.48，跳过此次更新
# 警告：梯度范数过大 77.15，跳过此次更新
# 警告：梯度范数过大 59.71，跳过此次更新
# 警告：梯度范数过大 58.69，跳过此次更新
# 警告：梯度范数过大 55.23，跳过此次更新
# 警告：梯度范数过大 68.93，跳过此次更新
# 警告：梯度范数过大 147.60，跳过此次更新
# 警告：梯度范数过大 70.40，跳过此次更新
# 警告：梯度范数过大 57.61，跳过此次更新
# 警告：梯度范数过大 58.07，跳过此次更新
# 警告：梯度范数过大 67.49，跳过此次更新
# 警告：梯度范数过大 85.83，跳过此次更新
# 警告：梯度范数过大 60.27，跳过此次更新
# 警告：梯度范数过大 80.21，跳过此次更新
# 警告：梯度范数过大 85.37，跳过此次更新
# 警告：梯度范数过大 49.51，跳过此次更新
# 警告：梯度范数过大 66.70，跳过此次更新
# 警告：梯度范数过大 74.40，跳过此次更新
# 警告：梯度范数过大 114.53，跳过此次更新
# 警告：梯度范数过大 81.60，跳过此次更新
# 警告：梯度范数过大 86.45，跳过此次更新
# 警告：梯度范数过大 54.98，跳过此次更新
# 警告：梯度范数过大 80.32，跳过此次更新
# 警告：梯度范数过大 71.75，跳过此次更新
# 警告：梯度范数过大 66.30，跳过此次更新
# 警告：梯度范数过大 79.19，跳过此次更新
# 警告：梯度范数过大 84.05，跳过此次更新
# 警告：梯度范数过大 51.25，跳过此次更新
# 警告：梯度范数过大 100.14，跳过此次更新
# 警告：梯度范数过大 119.04，跳过此次更新
# 警告：梯度范数过大 56.07，跳过此次更新
# 警告：梯度范数过大 88.89，跳过此次更新
# 警告：梯度范数过大 74.83，跳过此次更新
# 警告：梯度范数过大 93.17，跳过此次更新
# 警告：梯度范数过大 78.33，跳过此次更新
# 警告：梯度范数过大 57.69，跳过此次更新
# 警告：梯度范数过大 80.37，跳过此次更新
# 警告：梯度范数过大 122.10，跳过此次更新
# 警告：梯度范数过大 99.50，跳过此次更新
# 警告：梯度范数过大 66.38，跳过此次更新
# 警告：梯度范数过大 49.67，跳过此次更新
# 警告：梯度范数过大 105.43，跳过此次更新
# 警告：梯度范数过大 38.94，跳过此次更新
# 警告：梯度范数过大 79.28，跳过此次更新
# 警告：梯度范数过大 107.64，跳过此次更新
# 警告：梯度范数过大 61.91，跳过此次更新
# 警告：梯度范数过大 114.03，跳过此次更新
# 警告：梯度范数过大 22.83，跳过此次更新
# 警告：梯度范数过大 76.46，跳过此次更新
# 警告：梯度范数过大 49.65，跳过此次更新
# 警告：梯度范数过大 83.20，跳过此次更新
# 警告：梯度范数过大 79.76，跳过此次更新
# 警告：梯度范数过大 86.30，跳过此次更新
# 警告：梯度范数过大 37.18，跳过此次更新
# 警告：梯度范数过大 63.66，跳过此次更新
# 警告：梯度范数过大 49.20，跳过此次更新
# 警告：梯度范数过大 39.85，跳过此次更新
# 警告：梯度范数过大 74.82，跳过此次更新
# 警告：梯度范数过大 54.22，跳过此次更新
# 警告：梯度范数过大 58.37，跳过此次更新
# 警告：梯度范数过大 94.07，跳过此次更新
# 警告：梯度范数过大 54.92，跳过此次更新
# 警告：梯度范数过大 111.15，跳过此次更新
# 警告：梯度范数过大 60.90，跳过此次更新
# 警告：梯度范数过大 44.97，跳过此次更新
# 警告：梯度范数过大 96.12，跳过此次更新
# 警告：梯度范数过大 62.82，跳过此次更新
# 警告：梯度范数过大 125.45，跳过此次更新
# 警告：梯度范数过大 88.56，跳过此次更新
# 警告：梯度范数过大 83.14，跳过此次更新
# 警告：梯度范数过大 56.48，跳过此次更新
# 警告：梯度范数过大 70.45，跳过此次更新
# 警告：梯度范数过大 95.92，跳过此次更新
# 警告：梯度范数过大 81.57，跳过此次更新
# 警告：梯度范数过大 90.95，跳过此次更新
# 警告：梯度范数过大 34.97，跳过此次更新
# 警告：梯度范数过大 63.31，跳过此次更新
# 警告：梯度范数过大 64.24，跳过此次更新
# 警告：梯度范数过大 60.90，跳过此次更新
# 警告：梯度范数过大 85.78，跳过此次更新
# 警告：梯度范数过大 86.88，跳过此次更新
# 警告：梯度范数过大 75.03，跳过此次更新
# 警告：梯度范数过大 90.40，跳过此次更新
# 警告：梯度范数过大 72.39，跳过此次更新
# 警告：梯度范数过大 103.35，跳过此次更新
# 警告：梯度范数过大 69.11，跳过此次更新
# 警告：梯度范数过大 94.71，跳过此次更新
# 警告：梯度范数过大 56.03，跳过此次更新
# 警告：梯度范数过大 84.51，跳过此次更新
# 警告：梯度范数过大 41.16，跳过此次更新
# 警告：梯度范数过大 82.48，跳过此次更新
# 警告：梯度范数过大 75.32，跳过此次更新
# 警告：梯度范数过大 75.09，跳过此次更新
# 警告：梯度范数过大 66.25，跳过此次更新
# 警告：梯度范数过大 52.76，跳过此次更新
# 警告：梯度范数过大 43.94，跳过此次更新
# 警告：梯度范数过大 54.86，跳过此次更新
# 警告：梯度范数过大 91.95，跳过此次更新
# 警告：梯度范数过大 61.17，跳过此次更新
# 警告：梯度范数过大 61.49，跳过此次更新
# 警告：梯度范数过大 89.45，跳过此次更新
# 警告：梯度范数过大 44.34，跳过此次更新
# 警告：梯度范数过大 92.62，跳过此次更新
# 警告：梯度范数过大 108.25，跳过此次更新
# 警告：梯度范数过大 98.13，跳过此次更新
# 警告：梯度范数过大 54.11，跳过此次更新
# 警告：梯度范数过大 106.36，跳过此次更新
# 警告：梯度范数过大 84.02，跳过此次更新
# 警告：梯度范数过大 101.18，跳过此次更新
# 警告：梯度范数过大 68.47，跳过此次更新
# 警告：梯度范数过大 88.06，跳过此次更新
# 警告：梯度范数过大 64.65，跳过此次更新
# 警告：梯度范数过大 85.42，跳过此次更新
# 警告：梯度范数过大 95.69，跳过此次更新
# 警告：梯度范数过大 72.92，跳过此次更新
# 警告：梯度范数过大 64.21，跳过此次更新
# 警告：梯度范数过大 60.40，跳过此次更新
# 警告：梯度范数过大 58.51，跳过此次更新
# 警告：梯度范数过大 48.77，跳过此次更新
# 警告：梯度范数过大 64.76，跳过此次更新
# 警告：梯度范数过大 27.23，跳过此次更新
# 警告：梯度范数过大 64.17，跳过此次更新
# 警告：梯度范数过大 37.39，跳过此次更新
# 警告：梯度范数过大 76.20，跳过此次更新
# 警告：梯度范数过大 37.34，跳过此次更新
# 警告：梯度范数过大 100.49，跳过此次更新
# 警告：梯度范数过大 86.00，跳过此次更新
# 警告：梯度范数过大 69.84，跳过此次更新
# 警告：梯度范数过大 119.36，跳过此次更新
# 警告：梯度范数过大 55.16，跳过此次更新
# 警告：梯度范数过大 65.47，跳过此次更新
# 警告：梯度范数过大 61.53，跳过此次更新
# 警告：梯度范数过大 63.71，跳过此次更新
# 警告：梯度范数过大 56.19，跳过此次更新
# 警告：梯度范数过大 114.63，跳过此次更新
# 警告：梯度范数过大 81.12，跳过此次更新
# 警告：梯度范数过大 79.62，跳过此次更新
# 警告：梯度范数过大 27.60，跳过此次更新
# 警告：梯度范数过大 79.98，跳过此次更新
# 警告：梯度范数过大 81.56，跳过此次更新
# 警告：梯度范数过大 45.95，跳过此次更新
# 警告：梯度范数过大 76.69，跳过此次更新
# 警告：梯度范数过大 74.19，跳过此次更新
# 警告：梯度范数过大 53.87，跳过此次更新
# 警告：梯度范数过大 85.77，跳过此次更新
# 警告：梯度范数过大 84.08，跳过此次更新
# 警告：梯度范数过大 58.85，跳过此次更新
# 警告：梯度范数过大 60.57，跳过此次更新
# 警告：梯度范数过大 82.48，跳过此次更新
# 警告：梯度范数过大 81.98，跳过此次更新
# 警告：梯度范数过大 82.69，跳过此次更新
# 警告：梯度范数过大 42.16，跳过此次更新
# 警告：梯度范数过大 68.33，跳过此次更新
# 警告：梯度范数过大 74.64，跳过此次更新
# 警告：梯度范数过大 91.06，跳过此次更新
# 警告：梯度范数过大 97.47，跳过此次更新
# 警告：梯度范数过大 123.34，跳过此次更新
# 警告：梯度范数过大 74.67，跳过此次更新
# 警告：梯度范数过大 83.64，跳过此次更新
# 警告：梯度范数过大 105.50，跳过此次更新
# 警告：梯度范数过大 76.65，跳过此次更新
# 警告：梯度范数过大 54.35，跳过此次更新
# 警告：梯度范数过大 95.04，跳过此次更新
# 警告：梯度范数过大 61.28，跳过此次更新
# 警告：梯度范数过大 62.55，跳过此次更新
# 警告：梯度范数过大 51.20，跳过此次更新
# 警告：梯度范数过大 91.07，跳过此次更新
# 警告：梯度范数过大 82.79，跳过此次更新
# 警告：梯度范数过大 44.72，跳过此次更新
# 警告：梯度范数过大 88.67，跳过此次更新
# 警告：梯度范数过大 108.19，跳过此次更新
# 警告：梯度范数过大 63.24，跳过此次更新
# 警告：梯度范数过大 79.59，跳过此次更新
# 警告：梯度范数过大 76.68，跳过此次更新
# 警告：梯度范数过大 85.78，跳过此次更新
# 警告：梯度范数过大 31.47，跳过此次更新
# 警告：梯度范数过大 78.28，跳过此次更新
# 警告：梯度范数过大 65.19，跳过此次更新
# 警告：梯度范数过大 86.69，跳过此次更新
# 警告：梯度范数过大 36.90，跳过此次更新
# 警告：梯度范数过大 78.85，跳过此次更新
# 警告：梯度范数过大 65.87，跳过此次更新
# 警告：梯度范数过大 61.58，跳过此次更新
# 警告：梯度范数过大 72.29，跳过此次更新
# 警告：梯度范数过大 73.92，跳过此次更新
# 警告：梯度范数过大 65.76，跳过此次更新
# 警告：梯度范数过大 84.16，跳过此次更新
# 警告：梯度范数过大 93.86，跳过此次更新
# 警告：梯度范数过大 57.57，跳过此次更新
# 警告：梯度范数过大 69.99，跳过此次更新
# 警告：梯度范数过大 53.16，跳过此次更新
# 警告：梯度范数过大 50.99，跳过此次更新
# 警告：梯度范数过大 70.79，跳过此次更新
# Epoch 1/30: Train Loss: 0.884305, Val Loss: 0.405323, LR: 0.000050
# 保存最佳模型，验证损失: 0.405323
# 警告：梯度范数过大 85.76，跳过此次更新
# 警告：梯度范数过大 74.52，跳过此次更新
# 警告：梯度范数过大 47.60，跳过此次更新
# 警告：梯度范数过大 44.37，跳过此次更新
# 警告：梯度范数过大 69.84，跳过此次更新
# 警告：梯度范数过大 54.44，跳过此次更新
# 警告：梯度范数过大 85.42，跳过此次更新
# 警告：梯度范数过大 43.96，跳过此次更新
# 警告：梯度范数过大 45.72，跳过此次更新
# 警告：梯度范数过大 82.10，跳过此次更新
# 警告：梯度范数过大 107.02，跳过此次更新
# 警告：梯度范数过大 75.37，跳过此次更新
# 警告：梯度范数过大 45.72，跳过此次更新
# 警告：梯度范数过大 90.89，跳过此次更新
# 警告：梯度范数过大 100.67，跳过此次更新
# 警告：梯度范数过大 96.43，跳过此次更新
# 警告：梯度范数过大 43.72，跳过此次更新
# 警告：梯度范数过大 53.49，跳过此次更新
# 警告：梯度范数过大 64.68，跳过此次更新
# 警告：梯度范数过大 99.67，跳过此次更新
# 警告：梯度范数过大 62.53，跳过此次更新
# 警告：梯度范数过大 95.14，跳过此次更新
# 警告：梯度范数过大 94.46，跳过此次更新
# 警告：梯度范数过大 55.91，跳过此次更新
# 警告：梯度范数过大 66.81，跳过此次更新
# 警告：梯度范数过大 67.65，跳过此次更新
# 警告：梯度范数过大 59.53，跳过此次更新
# 警告：梯度范数过大 80.37，跳过此次更新
# 警告：梯度范数过大 93.74，跳过此次更新
# 警告：梯度范数过大 66.09，跳过此次更新
# 警告：梯度范数过大 83.24，跳过此次更新
# 警告：梯度范数过大 65.18，跳过此次更新
# 警告：梯度范数过大 120.80，跳过此次更新
# 警告：梯度范数过大 87.51，跳过此次更新
# 警告：梯度范数过大 72.45，跳过此次更新
# 警告：梯度范数过大 67.17，跳过此次更新
# 警告：梯度范数过大 60.88，跳过此次更新
# 警告：梯度范数过大 52.63，跳过此次更新
# 警告：梯度范数过大 83.76，跳过此次更新
# 警告：梯度范数过大 59.45，跳过此次更新
# 警告：梯度范数过大 69.11，跳过此次更新
# 警告：梯度范数过大 47.44，跳过此次更新
# 警告：梯度范数过大 80.51，跳过此次更新
# 警告：梯度范数过大 95.51，跳过此次更新
# 警告：梯度范数过大 49.20，跳过此次更新
# 警告：梯度范数过大 71.74，跳过此次更新
# 警告：梯度范数过大 73.70，跳过此次更新
# 警告：梯度范数过大 121.33，跳过此次更新
# 警告：梯度范数过大 78.45，跳过此次更新
# 警告：梯度范数过大 79.86，跳过此次更新
# 警告：梯度范数过大 74.20，跳过此次更新
# 警告：梯度范数过大 95.02，跳过此次更新
# 警告：梯度范数过大 58.25，跳过此次更新
# 警告：梯度范数过大 35.31，跳过此次更新
# 警告：梯度范数过大 66.14，跳过此次更新
# 警告：梯度范数过大 71.63，跳过此次更新
# 警告：梯度范数过大 58.76，跳过此次更新
# 警告：梯度范数过大 45.37，跳过此次更新
# 警告：梯度范数过大 55.70，跳过此次更新
# 警告：梯度范数过大 89.11，跳过此次更新
# 警告：梯度范数过大 93.55，跳过此次更新
# 警告：梯度范数过大 91.49，跳过此次更新
# 警告：梯度范数过大 66.69，跳过此次更新
# 警告：梯度范数过大 115.94，跳过此次更新
# 警告：梯度范数过大 76.73，跳过此次更新
# 警告：梯度范数过大 55.31，跳过此次更新
# 警告：梯度范数过大 57.51，跳过此次更新
# 警告：梯度范数过大 98.17，跳过此次更新
# 警告：梯度范数过大 75.14，跳过此次更新
# 警告：梯度范数过大 55.84，跳过此次更新
# 警告：梯度范数过大 78.10，跳过此次更新
# 警告：梯度范数过大 58.26，跳过此次更新
# 警告：梯度范数过大 57.72，跳过此次更新
# 警告：梯度范数过大 78.32，跳过此次更新
# 警告：梯度范数过大 66.68，跳过此次更新
# 警告：梯度范数过大 77.95，跳过此次更新
# 警告：梯度范数过大 70.36，跳过此次更新
# 警告：梯度范数过大 39.13，跳过此次更新
# 警告：梯度范数过大 59.60，跳过此次更新
# 警告：梯度范数过大 46.17，跳过此次更新
# 警告：梯度范数过大 74.49，跳过此次更新
# 警告：梯度范数过大 76.82，跳过此次更新
# 警告：梯度范数过大 67.31，跳过此次更新
# 警告：梯度范数过大 66.51，跳过此次更新
# 警告：梯度范数过大 61.86，跳过此次更新
# 警告：梯度范数过大 65.61，跳过此次更新
# 警告：梯度范数过大 64.62，跳过此次更新
# 警告：梯度范数过大 85.98，跳过此次更新
# 警告：梯度范数过大 38.27，跳过此次更新
# 警告：梯度范数过大 109.43，跳过此次更新
# 警告：梯度范数过大 50.04，跳过此次更新
# 警告：梯度范数过大 33.38，跳过此次更新
# 警告：梯度范数过大 52.73，跳过此次更新
# 警告：梯度范数过大 100.01，跳过此次更新
# 警告：梯度范数过大 56.80，跳过此次更新
# 警告：梯度范数过大 86.50，跳过此次更新
# 警告：梯度范数过大 79.45，跳过此次更新
# 警告：梯度范数过大 73.26，跳过此次更新
# 警告：梯度范数过大 87.46，跳过此次更新
# 警告：梯度范数过大 67.74，跳过此次更新
# 警告：梯度范数过大 100.81，跳过此次更新
# 警告：梯度范数过大 69.62，跳过此次更新
# 警告：梯度范数过大 62.00，跳过此次更新
# 警告：梯度范数过大 36.02，跳过此次更新
# 警告：梯度范数过大 79.33，跳过此次更新
# 警告：梯度范数过大 59.17，跳过此次更新
# 警告：梯度范数过大 66.67，跳过此次更新
# 警告：梯度范数过大 87.56，跳过此次更新
# 警告：梯度范数过大 60.11，跳过此次更新
# 警告：梯度范数过大 75.44，跳过此次更新
# 警告：梯度范数过大 103.84，跳过此次更新
# 警告：梯度范数过大 38.54，跳过此次更新
# 警告：梯度范数过大 56.97，跳过此次更新
# 警告：梯度范数过大 65.50，跳过此次更新
# 警告：梯度范数过大 124.97，跳过此次更新
# 警告：梯度范数过大 48.32，跳过此次更新
# 警告：梯度范数过大 66.37，跳过此次更新
# 警告：梯度范数过大 83.14，跳过此次更新
# 警告：梯度范数过大 79.86，跳过此次更新
# 警告：梯度范数过大 72.02，跳过此次更新
# 警告：梯度范数过大 94.46，跳过此次更新
# 警告：梯度范数过大 89.10，跳过此次更新
# 警告：梯度范数过大 62.49，跳过此次更新
# 警告：梯度范数过大 93.13，跳过此次更新
# 警告：梯度范数过大 59.06，跳过此次更新
# 警告：梯度范数过大 66.82，跳过此次更新
# 警告：梯度范数过大 75.59，跳过此次更新
# 警告：梯度范数过大 31.89，跳过此次更新
# 警告：梯度范数过大 82.82，跳过此次更新
# 警告：梯度范数过大 85.42，跳过此次更新
# 警告：梯度范数过大 132.81，跳过此次更新
# 警告：梯度范数过大 78.89，跳过此次更新
# 警告：梯度范数过大 86.26，跳过此次更新
# 警告：梯度范数过大 66.14，跳过此次更新
# 警告：梯度范数过大 92.86，跳过此次更新
# 警告：梯度范数过大 93.07，跳过此次更新
# 警告：梯度范数过大 91.39，跳过此次更新
# 警告：梯度范数过大 42.62，跳过此次更新
# 警告：梯度范数过大 27.56，跳过此次更新
# 警告：梯度范数过大 49.96，跳过此次更新
# 警告：梯度范数过大 45.20，跳过此次更新
# 警告：梯度范数过大 66.50，跳过此次更新
# 警告：梯度范数过大 93.93，跳过此次更新
# 警告：梯度范数过大 48.65，跳过此次更新
# 警告：梯度范数过大 105.47，跳过此次更新
# 警告：梯度范数过大 47.52，跳过此次更新
# 警告：梯度范数过大 46.59，跳过此次更新
# 警告：梯度范数过大 66.37，跳过此次更新
# 警告：梯度范数过大 75.58，跳过此次更新
# 警告：梯度范数过大 73.25，跳过此次更新
# 警告：梯度范数过大 68.60，跳过此次更新
# 警告：梯度范数过大 44.70，跳过此次更新
# 警告：梯度范数过大 84.90，跳过此次更新
# 警告：梯度范数过大 59.02，跳过此次更新
# 警告：梯度范数过大 60.99，跳过此次更新
# 警告：梯度范数过大 86.62，跳过此次更新
# 警告：梯度范数过大 79.56，跳过此次更新
# 警告：梯度范数过大 59.25，跳过此次更新
# 警告：梯度范数过大 43.51，跳过此次更新
# 警告：梯度范数过大 54.15，跳过此次更新
# 警告：梯度范数过大 61.58，跳过此次更新
# 警告：梯度范数过大 64.08，跳过此次更新
# 警告：梯度范数过大 93.95，跳过此次更新
# 警告：梯度范数过大 29.61，跳过此次更新
# 警告：梯度范数过大 82.59，跳过此次更新
# 警告：梯度范数过大 43.34，跳过此次更新
# 警告：梯度范数过大 136.62，跳过此次更新
# 警告：梯度范数过大 68.73，跳过此次更新
# 警告：梯度范数过大 69.61，跳过此次更新
# 警告：梯度范数过大 111.64，跳过此次更新
# 警告：梯度范数过大 79.23，跳过此次更新
# 警告：梯度范数过大 46.35，跳过此次更新
# 警告：梯度范数过大 86.67，跳过此次更新
# 警告：梯度范数过大 89.86，跳过此次更新
# 警告：梯度范数过大 77.76，跳过此次更新
# 警告：梯度范数过大 61.74，跳过此次更新
# 警告：梯度范数过大 77.41，跳过此次更新
# 警告：梯度范数过大 70.32，跳过此次更新
# 警告：梯度范数过大 51.65，跳过此次更新
# 警告：梯度范数过大 54.96，跳过此次更新
# 警告：梯度范数过大 46.47，跳过此次更新
# 警告：梯度范数过大 36.43，跳过此次更新
# 警告：梯度范数过大 57.76，跳过此次更新
# 警告：梯度范数过大 55.75，跳过此次更新
# 警告：梯度范数过大 58.71，跳过此次更新
# 警告：梯度范数过大 101.92，跳过此次更新
# 警告：梯度范数过大 70.91，跳过此次更新
# 警告：梯度范数过大 90.92，跳过此次更新
# 警告：梯度范数过大 54.64，跳过此次更新
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 456
#     453         traceback.print_exc()
#     455 if __name__ == "__main__":
# --> 456     main()
#
# Cell In[57], line 432, in main()
#     430 # 3. 运行模型对比实验
#     431 print("\n运行模型对比实验...")
# --> 432 temperature_results = experiment.run_model_comparison('Temperature')
#     434 # 4. 绘制对比结果
#     435 experiment.plot_comparison_results(temperature_results, 'Temperature')
#
# Cell In[57], line 225, in WeatherForecastingExperiment.run_model_comparison(self, target_variable)
#     223 # 训练模型 - 使用更低的学习率
#     224 trainer = ModelTrainer(model, self.device, learning_rate=0.00005)
# --> 225 trained_model = trainer.train(train_loader, val_loader, epochs=30, patience=8)
#     227 # 评估模型
#     228 evaluator = ModelEvaluator(trained_model, self.device)
#
# Cell In[55], line 247, in ModelTrainer.train(self, train_loader, val_loader, epochs, patience)
#     244 print(f"开始训练，初始学习率: {self.optimizer.param_groups[0]['lr']:.6f}")
#     246 for epoch in range(epochs):
# --> 247     train_loss = self.train_epoch(train_loader)
#     248     val_loss = self.validate(val_loader)
#     250     # 学习率调度
#
# Cell In[55], line 191, in ModelTrainer.train_epoch(self, train_loader)
#     188 self.optimizer.zero_grad()
#     190 try:
# --> 191     outputs = self.model(batch_x)
#     192     loss = self.criterion(outputs, batch_y)
#     194     # 检查损失是否异常
#
# File c:\Users\W1770\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\W1770\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[54], line 324, in LocalAttentionTransformer.forward(self, x)
#     319 # 局部注意力层
#     320 for i, (local_attn, layer_norm, ff) in enumerate(zip(
#     321     self.local_attention_layers, self.layer_norms, self.feed_forwards
#     322 )):
#     323     # 局部注意力
# --> 324     attn_output = local_attn(x)
#     325     x = layer_norm(x + attn_output)
#     327     # 前馈网络
#
# File c:\Users\W1770\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\W1770\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[54], line 364, in LocalAttentionLayer.forward(self, x)
#     361 V = self.v_linear(x).view(batch_size, seq_len, self.nhead, self.head_dim).transpose(1, 2)
#     363 # 创建局部注意力掩码
# --> 364 mask = self.create_local_mask(seq_len, self.local_window, x.device)
#     366 # 计算注意力分数
#     367 scores = torch.matmul(Q, K.transpose(-2, -1)) / np.sqrt(self.head_dim)
#
# Cell In[54], line 385, in LocalAttentionLayer.create_local_mask(self, seq_len, window_size, device)
#     383     start = max(0, i - window_size // 2)
#     384     end = min(seq_len, i + window_size // 2 + 1)
# --> 385     mask[i, start:end] = 1
#     386 return mask.unsqueeze(0).unsqueeze(0)
#
# KeyboardInterrupt:
